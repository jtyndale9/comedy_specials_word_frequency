# %%
import nltk
from pathlib import PurePath
from nltk.corpus import stopwords
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\john4\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
path = PurePath(r'C:\Users\john4\Documents\Software Development\Comedy Data Viz\Comedy_Transcripts')
#print("Path: " , path)
file = r'Kevin_Hart_zero_fucks.txt'
file1 = path / file
print("Path: \n", file1)
# Out:
# Path:
#  C:\Users\john4\Documents\Software Development\Comedy Data Viz\Comedy_Transcripts\Kevin_Hart_zero_fucks.txt

# %%
file1_read = open(file1, encoding='utf-8')
file1_data = file1_read.read()
#print(file1_data) #this has the whole text file raw data saved in it

tokens = nltk.word_tokenize(file1_data)
#print("tokens: \n", tokens) # this contains all messy tokens, capitals, and non characters like '['
tokens=[word.lower() for word in tokens if word.isalpha()] #change everything to lowercase
#print("tokens: \n", tokens) # this contains all cleaned up lower case words
fdist1 = nltk.FreqDist(tokens)
print(fdist1)
# Out:
# <FreqDist with 1424 samples and 11698 outcomes>

# %%
filtered_word_freq = dict((word, freq) for word, freq in fdist1.items() if not word.isdigit())
#print(filtered_word_freq) # This contains the amount of times a word appears in the token list
print("type: ", type(filtered_word_freq))
# Out:
# type:  <class 'dict'>

# %%
for key, value in filtered_word_freq.items():
    print(key, '->', value)
# Out:
# i -> 691
# can -> 45
# say -> 20
# hello -> 4
# first -> 12
# time -> 34
# ve -> 22
# been -> 15
# this -> 94
# intimate -> 2
# with -> 57
# a -> 224
# crowd -> 28
# so -> 23
# and -> 74
# actually -> 8
# get -> 96
# back -> 35
# mma -> 13
# it -> 236
# again -> 15
# how -> 39
# y -> 12
# all -> 73
# doing -> 17
# good -> 39
# cheering -> 4
# that -> 194
# s -> 222
# like -> 63
# feels -> 5
# right -> 45
# to -> 230
# me -> 145
# woman -> 9
# yeah -> 6
# in -> 140
# lot -> 15
# of -> 118
# different -> 10
# spaces -> 1
# tell -> 19
# some -> 41
# jokes -> 7
# f -> 194
# cking -> 95
# stadiums -> 1
# arenas -> 1
# theaters -> 1
# now -> 15
# the -> 381
# comfort -> 2
# my -> 210
# own -> 1
# home -> 8
# thank -> 8
# you -> 378
# applauding -> 12
# getting -> 20
# basics -> 1
# wan -> 13
# na -> 60
# explain -> 3
# guys -> 21
# why -> 32
# m -> 112
# house -> 22
# we -> 67
# re -> 44
# here -> 42
# for -> 80
# reason -> 6
# no -> 53
# longer -> 3
# comfortable -> 4
# anywhere -> 3
# ...

# %%
# Sort it so you get the most commonly used words on top
sorted_dict = sorted(filtered_word_freq, key=filtered_word_freq.get, reverse=True)
type(sorted_dict)
sorted_dict
# Out:
# ['i',
#  'the',
#  'you',
#  'it',
#  'to',
#  'a',
#  's',
#  'my',
#  't',
#  'that',
#  'f',
#  'me',
#  'in',
#  'what',
#  'got',
#  'of',
#  'm',
#  'was',
#  'don',
#  'get',
#  'cking',
#  'this',
#  'he',
#  'for',
#  'said',
#  'on',
#  'and',
#  'is',
#  'all',
#  'know',
#  'they',
#  'we',
#  'ck',
#  'out',
#  'like',
#  'na',
#  'not',
#  'with',
#  'at',
#  'no',
#  'had',
#  'just',
#  'do',
#  'your',
#  'man',
#  'are',
#  'go',
#  'gon',
#  'about',
#  'can',
#  'right',
#  're',
#  'ta',
#  'be',
#  'here',
#  'some',
#  'she',
#  'how',
#  'good',
#  'have',
#  'there',
#  'shit',
#  'back',
#  'time',
#  'why',
#  'up',
#  'see',
#  'kids',
#  'ain',
#  'people',
#  'crowd',
#  'if',
#  'went',
#  'one',
#  'told',
#  'come',
#  'chuckles',
#  'didn',
#  'who',
#  'want',
#  'but',
#  'over',
#  'going',
#  'ckin',
#  'so',
#  'll',
#  'oh',
#  'more',
#  've',
#  'house',
#  'give',
#  'guys',
#  'when',
#  'b',
#  'as',
#  'her',
#  'him',
#  'from',
# ...

# %%
sorted_values = sorted(filtered_word_freq.values(), reverse=True) # Sort the values
sorted_dict = {}

for i in sorted_values:
    for k in filtered_word_freq.keys():
        if filtered_word_freq[k] == i:
            sorted_dict[k] = filtered_word_freq[k]

# %%
for key, value in sorted_dict.items():
    print(key, '->', value)
# Out:
# i -> 691
# the -> 381
# you -> 378
# it -> 236
# to -> 230
# a -> 224
# s -> 222
# my -> 210
# t -> 199
# that -> 194
# f -> 194
# me -> 145
# in -> 140
# what -> 133
# got -> 119
# of -> 118
# m -> 112
# was -> 100
# don -> 99
# get -> 96
# cking -> 95
# this -> 94
# he -> 83
# for -> 80
# said -> 80
# on -> 80
# and -> 74
# is -> 74
# all -> 73
# know -> 70
# they -> 68
# we -> 67
# ck -> 65
# out -> 65
# like -> 63
# na -> 60
# not -> 58
# with -> 57
# at -> 56
# no -> 53
# had -> 53
# just -> 53
# do -> 53
# your -> 52
# man -> 52
# are -> 48
# go -> 48
# gon -> 46
# about -> 46
# can -> 45
# right -> 45
# re -> 44
# ta -> 44
# be -> 43
# here -> 42
# some -> 41
# she -> 40
# how -> 39
# good -> 39
# have -> 39
# there -> 38
# shit -> 36
# back -> 35
# time -> 34
# why -> 32
# up -> 32
# see -> 32
# kids -> 32
# ain -> 29
# people -> 29
# crowd -> 28
# if -> 28
# went -> 28
# one -> 27
# told -> 27
# come -> 27
# chuckles -> 26
# didn -> 26
# who -> 26
# want -> 26
# but -> 25
# ...

# %%
#print(stopwords.words('english'))
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# Take all stop words out of the data
new_dict = {}

for key, value in sorted_dict.items():
    if key not in stop_words:
        new_dict[key] = value

# %%
new_dict
# Out:
# {'f': 194,
#  'got': 119,
#  'get': 96,
#  'cking': 95,
#  'said': 80,
#  'know': 70,
#  'ck': 65,
#  'like': 63,
#  'na': 60,
#  'man': 52,
#  'go': 48,
#  'gon': 46,
#  'right': 45,
#  'ta': 44,
#  'good': 39,
#  'shit': 36,
#  'back': 35,
#  'time': 34,
#  'see': 32,
#  'kids': 32,
#  'people': 29,
#  'crowd': 28,
#  'went': 28,
#  'one': 27,
#  'told': 27,
#  'come': 27,
#  'chuckles': 26,
#  'want': 26,
#  'going': 25,
#  'ckin': 25,
#  'oh': 23,
#  'house': 22,
#  'give': 22,
#  'guys': 21,
#  'b': 21,
#  'bop': 21,
#  'say': 20,
#  'getting': 20,
#  'wife': 20,
#  'tell': 19,
#  'ass': 19,
#  'would': 18,
#  'could': 18,
#  'never': 18,
#  'feel': 17,
#  'let': 17,
#  'vid': 17,
#  'take': 17,
#  'okay': 17,
#  'dick': 17,
#  'thing': 16,
#  'put': 16,
#  'day': 16,
#  'look': 16,
#  'lot': 15,
#  'kevin': 15,
#  'god': 15,
#  'every': 15,
#  'wanted': 15,
#  'start': 15,
#  'talking': 15,
#  'cause': 15,
#  'way': 14,
#  'make': 14,
#  'outside': 14,
#  'better': 14,
# ...

# %%
for key, value in new_dict.items():
    print(key, '->', value)
# Out:
# f -> 194
# got -> 119
# get -> 96
# cking -> 95
# said -> 80
# know -> 70
# ck -> 65
# like -> 63
# na -> 60
# man -> 52
# go -> 48
# gon -> 46
# right -> 45
# ta -> 44
# good -> 39
# shit -> 36
# back -> 35
# time -> 34
# see -> 32
# kids -> 32
# people -> 29
# crowd -> 28
# went -> 28
# one -> 27
# told -> 27
# come -> 27
# chuckles -> 26
# want -> 26
# going -> 25
# ckin -> 25
# oh -> 23
# house -> 22
# give -> 22
# guys -> 21
# b -> 21
# bop -> 21
# say -> 20
# getting -> 20
# wife -> 20
# tell -> 19
# ass -> 19
# would -> 18
# could -> 18
# never -> 18
# feel -> 17
# let -> 17
# vid -> 17
# take -> 17
# okay -> 17
# dick -> 17
# thing -> 16
# put -> 16
# day -> 16
# look -> 16
# lot -> 15
# kevin -> 15
# god -> 15
# every -> 15
# wanted -> 15
# start -> 15
# talking -> 15
# cause -> 15
# way -> 14
# make -> 14
# outside -> 14
# better -> 14
# stop -> 14
# pizza -> 14
# mma -> 13
# wan -> 13
# else -> 13
# honest -> 13
# somebody -> 13
# call -> 13
# need -> 13
# old -> 13
# ...

# %%
useless_words = ['gon', 'go', 'know', 'right', 'got', 'one', 'get', 'yeah', 'good', 'go', 'thank', 'say', 'come', 'oh', 'make', 'really', 'two', 'applause', 
                 'let', 'going', 'audience', 'made', 'way', 'us', 'see', 'great', 'want', 'lot', 'way', 'ta', 'take', 'cause', 'attell', 'something',
                 'em', 'real', 'better', 'wan', 'show', 'back', 'well', 'even', 'never', 'tell', 'keep', 'away', 'much', 'things', 'time', 'ever'
                'welcome', 'cause', 'please', 'okay', 'would', 'like', 'na', 'ever', 'laughs', 'goes', 'people', 'said', 'guy', 'claping', 'cheering', 'give'
                'day', 'clapping', 'clapping ', 'give', 'first', 'saying', 'ask', 'every', 'laughing', 'went', 'ricky', 'applauding', 'uh', 'laughter', 'f', 'ok'
                'ck', 'ok', 'ck ', ' ck', 'crowd']

# %%
new_dict_2 = {}

for key, value in new_dict.items():
    if key not in useless_words:
        new_dict_2[key] = value
for key, value in new_dict_2.items():
    print(key, '->', value)
# Out:
# cking -> 95
# ck -> 65
# man -> 52
# shit -> 36
# kids -> 32
# told -> 27
# chuckles -> 26
# ckin -> 25
# house -> 22
# guys -> 21
# b -> 21
# bop -> 21
# getting -> 20
# wife -> 20
# ass -> 19
# could -> 18
# feel -> 17
# vid -> 17
# dick -> 17
# thing -> 16
# put -> 16
# day -> 16
# look -> 16
# kevin -> 15
# god -> 15
# wanted -> 15
# start -> 15
# talking -> 15
# outside -> 14
# stop -> 14
# pizza -> 14
# mma -> 13
# else -> 13
# honest -> 13
# somebody -> 13
# call -> 13
# need -> 13
# old -> 13
# butter -> 13
# tch -> 12
# nobody -> 12
# came -> 12
# black -> 12
# life -> 12
# balls -> 12
# school -> 12
# thought -> 12
# josé -> 12
# hart -> 11
# face -> 11
# big -> 11
# matt -> 11
# called -> 11
# private -> 11
# seinfeld -> 11
# different -> 10
# level -> 10
# nothing -> 10
# crazy -> 10
# saw -> 10
# happening -> 10
# dad -> 10
# older -> 10
# schools -> 10
# amazing -> 10
# woman -> 9
# think -> 9
# everybody -> 9
# happened -> 9
# mimics -> 9
# left -> 9
# looking -> 9
# ...

# %%
races = ['black', 'white', 'yellow', 'asian']
race_dict = {}
for key, value in new_dict.items():
    if key in races:
        race_dict[key] = value

race_dict
# Out:
# {'black': 12, 'white': 9}

# %%
del new_dict_2['ck']

# %%
words = []
values = []

for i in range(20):
    words.append(list(new_dict_2.keys())[i])
    values.append(list(new_dict_2.values())[i])

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# plt.style.use('Solarize_Light2')
# plt.style.use('fivethirtyeight')
# plt.style.use('seaborn-pastel')
# plt.style.use('seaborn-white')
# plt.style.use('tableau-colorblind10')

# %%
plt.style.use('dark_background')

# %%
fig = plt.figure(figsize = (15, 20))

plt.rc('ytick', labelsize=13)
plt.barh(words,values)

plt.gca().invert_yaxis()
plt.grid(False)
plt.xlabel("# of Times Said", fontsize=15, fontweight='bold')
plt.ylabel("Words Used", fontsize=18, fontweight='bold')
plt.title("Most common words in 'TEMPLATE' by TEMPLATE", fontsize=15)

plt.savefig('TEMPLATE_graph.jpg',bbox_inches='tight', dpi=150)
plt.show()

# %%
useless_words_2 = ['b', 'could', 'vid ', 'thing','gon', 'go', 'know', 'right', 'got', 'one', 'get', 'yeah', 'good', 'go', 'thank', 'say', 'come', 'oh', 'make', 'really', 'two', 'applause', 
                 'let', 'going', 'audience', 'made', 'way', 'us', 'see', 'great', 'want', 'lot', 'way', 'ta', 'take', 'cause', 'attell', 'something',
                 'em', 'real', 'better', 'wan', 'show', 'back', 'well', 'even', 'never', 'tell', 'keep', 'away', 'much', 'things', 'time', 'ever'
                'welcome', 'cause', 'please', 'okay', 'would', 'like', 'na', 'ever', 'laughs', 'goes', 'people', 'said', 'guy', 'claping', 'cheering', 'give'
                'day', 'clapping', 'clapping ', 'give', 'first', 'saying', 'ask', 'every', 'laughing', 'went', 'ricky', 'applauding', 'uh', 'laughter', 'f', 'ok'
                'ck', 'ok', 'ck ', ' ck', 'crowd', 'chuckles', 'vid']

# %%
new_dict_3 = {}

fuck_count = 0

for key, value in new_dict.items():
    if key not in useless_words_2:
        if((key == 'cking') | (key == 'ckin') | (key == 'ck')):
            key = 'fuckin'
            fuck_count = fuck_count + value
            new_dict_3[key] = fuck_count
        else:
            new_dict_3[key] = value
for key, value in new_dict_3.items():
    print(key, '->', value)
# Out:
# fuckin -> 185
# man -> 52
# shit -> 36
# kids -> 32
# told -> 27
# house -> 22
# guys -> 21
# bop -> 21
# getting -> 20
# wife -> 20
# ass -> 19
# feel -> 17
# dick -> 17
# put -> 16
# day -> 16
# look -> 16
# kevin -> 15
# god -> 15
# wanted -> 15
# start -> 15
# talking -> 15
# outside -> 14
# stop -> 14
# pizza -> 14
# mma -> 13
# else -> 13
# honest -> 13
# somebody -> 13
# call -> 13
# need -> 13
# old -> 13
# butter -> 13
# tch -> 12
# nobody -> 12
# came -> 12
# black -> 12
# life -> 12
# balls -> 12
# school -> 12
# thought -> 12
# josé -> 12
# hart -> 11
# face -> 11
# big -> 11
# matt -> 11
# called -> 11
# private -> 11
# seinfeld -> 11
# different -> 10
# level -> 10
# nothing -> 10
# crazy -> 10
# saw -> 10
# happening -> 10
# dad -> 10
# older -> 10
# schools -> 10
# amazing -> 10
# woman -> 9
# think -> 9
# everybody -> 9
# happened -> 9
# mimics -> 9
# left -> 9
# looking -> 9
# dinner -> 9
# talk -> 9
# throw -> 9
# white -> 9
# chat -> 9
# eighth -> 9
# ...

# %%
words = []
values = []

for i in range(16):
    words.append(list(new_dict_3.keys())[i])
    values.append(list(new_dict_3.values())[i])

fig = plt.figure(figsize = (15, 20))

plt.rc('ytick', labelsize=13)
plt.barh(words,values)

plt.gca().invert_yaxis()
plt.grid(False)
plt.xlabel("# of Times Said", fontsize=15, fontweight='bold')
plt.ylabel("Words Used", fontsize=18, fontweight='bold')
plt.title("Most common words in 'Zero Fucks Given' by Kevin Hart", fontsize=15)

plt.savefig('zero_fucks_kevin.jpg',bbox_inches='tight', dpi=150)
plt.show()
