# %%
import nltk
from pathlib import PurePath
from nltk.corpus import stopwords
import numpy as np
import matplotlib.pyplot as plt

# %%
path = PurePath(r'C:\Users\john4\Documents\Software Development\Code Practice\Comedy_Transcripts')
#print("Path: " , path)
file = r'Tom_Segura_Disgraceful_2018.txt'
file1 = path / file
print("Path: \n", file1)
# Out:
# Path:
#  C:\Users\john4\Documents\Software Development\Code Practice\Comedy_Transcripts\Tom_Segura_Disgraceful_2018.txt

# %%
file1_read = open(file1, encoding='utf-8')
file1_data = file1_read.read()
#print(file1_data) #this has the whole text file raw data saved in it

tokens = nltk.word_tokenize(file1_data)
#print("tokens: \n", tokens) # this contains all messy tokens, capitals, and non characters like '['
tokens=[word.lower() for word in tokens if word.isalpha()] #change everything to lowercase
#print("tokens: \n", tokens) # this contains all cleaned up lower case words
fdist1 = nltk.FreqDist(tokens)
print(fdist1)
# Out:
# <FreqDist with 1455 samples and 10871 outcomes>

# %%
filtered_word_freq = dict((word, freq) for word, freq in fdist1.items() if not word.isdigit())
#print(filtered_word_freq) # This contains the amount of times a word appears in the token list
print("type: ", type(filtered_word_freq))
# Out:
# type:  <class 'dict'>

# %%
for key, value in filtered_word_freq.items():
    print(key, '->', value)
# Out:
# whoa -> 4
# what -> 78
# s -> 212
# up -> 51
# holy -> 3
# shit -> 29
# thank -> 5
# you -> 486
# denver -> 3
# that -> 208
# was -> 75
# amazing -> 4
# audience -> 402
# whooping -> 4
# so -> 58
# much -> 7
# i -> 585
# wish -> 3
# home -> 7
# right -> 34
# now -> 41
# laughs -> 380
# no -> 41
# offense -> 1
# not -> 54
# personal -> 2
# is -> 80
# literally -> 1
# my -> 100
# first -> 11
# thought -> 8
# whenever -> 1
# walk -> 6
# into -> 11
# any -> 8
# room -> 4
# m -> 100
# like -> 207
# well -> 16
# think -> 29
# it -> 193
# your -> 62
# too -> 7
# re -> 131
# hope -> 3
# this -> 58
# good -> 9
# but -> 47
# also -> 3
# wrap -> 2
# can -> 57
# go -> 107
# actually -> 2
# the -> 198
# meaning -> 5
# of -> 127
# life -> 13
# people -> 44
# are -> 72
# always -> 5
# philosophizing -> 1
# ll -> 48
# tell -> 25
# fuck -> 36
# place -> 6
# let -> 13
# laughing -> 9
# and -> 363
# whistling -> 2
# luckily -> 2
# for -> 46
# all -> 44
# us -> 10
# we -> 60
# five -> 2
# years -> 16
# away -> 7
# from -> 18
# never -> 20
# leaving -> 1
# our -> 14
# homes -> 2
# again -> 4
# pretty -> 5
# fuckin -> 36
# excited -> 3
# about -> 38
# there -> 37
# a -> 224
# lot -> 14
# indicators -> 1
# if -> 58
# paying -> 1
# attention -> 1
# number -> 4
# one -> 25
# do -> 54
# ever -> 15
# really -> 11
# process -> 1
# don -> 80
# t -> 129
# have -> 43
# to -> 161
# leave -> 8
# buy -> 3
# anything -> 5
# yeah -> 28
# order -> 2
# some -> 21
# things -> 1
# sit -> 8
# on -> 40
# couch -> 1
# pull -> 4
# phone -> 2
# want -> 40
# just -> 48
# be -> 50
# bananas -> 1
# hammers -> 1
# an -> 23
# eagle -> 1
# amazon -> 1
# blows -> 2
# raspberry -> 2
# how -> 27
# isn -> 7
# insane -> 1
# see -> 33
# should -> 16
# hold -> 3
# same -> 8
# device -> 1
# saw -> 8
# everyone -> 2
# indicator -> 2
# gon -> 29
# na -> 30
# day -> 13
# very -> 9
# soon -> 2
# commercials -> 2
# beds -> 2
# know -> 80
# talking -> 7
# haven -> 3
# been -> 16
# watching -> 1
# tv -> 1
# endless -> 1
# air -> 2
# where -> 12
# basically -> 2
# guy -> 31
# comes -> 5
# out -> 41
# he -> 141
# doesn -> 8
# suck -> 4
# something -> 11
# guess -> 2
# does -> 6
# goes -> 89
# get -> 46
# bed -> 8
# they -> 75
# try -> 7
# advertise -> 1
# snoring -> 1
# because -> 7
# piece -> 2
# why -> 37
# got -> 23
# ve -> 23
# done -> 3
# lay -> 2
# down -> 5
# sleeping -> 1
# hours -> 1
# when -> 30
# wake -> 2
# even -> 9
# here -> 23
# little -> 8
# turd -> 1
# change -> 6
# world -> 2
# means -> 6
# in -> 123
# two -> 8
# sitting -> 5
# then -> 41
# mechanical -> 1
# arm -> 1
# will -> 15
# come -> 11
# open -> 3
# bah -> 6
# through -> 14
# tired -> 4
# wan -> 1
# rest -> 4
# oh -> 17
# pounds -> 2
# wait -> 6
# speaking -> 5
# weight -> 8
# lost -> 3
# decent -> 1
# amount -> 1
# recently -> 4
# cheering -> 18
# loss -> 3
# contest -> 2
# with -> 27
# fattest -> 1
# man -> 21
# earth -> 1
# yes -> 4
# may -> 1
# seen -> 3
# him -> 25
# his -> 23
# name -> 6
# brent -> 1
# crystals -> 1
# beat -> 1
# better -> 6
# person -> 5
# talk -> 4
# maybe -> 5
# thinking -> 1
# hey -> 9
# probably -> 5
# mean -> 12
# look -> 17
# doing -> 8
# awesome -> 6
# clapping -> 19
# sucks -> 2
# lose -> 4
# public -> 3
# platform -> 1
# did -> 25
# many -> 6
# messages -> 2
# inspired -> 1
# didn -> 13
# ask -> 10
# me -> 74
# coach -> 2
# absolutely -> 2
# hit -> 4
# times -> 3
# give -> 15
# message -> 3
# mirror -> 1
# say -> 34
# hate -> 2
# ready -> 2
# cry -> 1
# more -> 17
# eat -> 7
# send -> 1
# asked -> 4
# grand -> 1
# scale -> 1
# who -> 16
# helping -> 1
# nobody -> 6
# starbucks -> 3
# true -> 2
# national -> 1
# training -> 1
# campaign -> 1
# trick -> 1
# ordering -> 1
# food -> 5
# going -> 11
# beverage -> 1
# lead -> 1
# greet -> 1
# welcome -> 1
# started -> 2
# today -> 5
# wanted -> 3
# else -> 4
# sausage -> 1
# respect -> 1
# shame -> 1
# honest -> 3
# than -> 10
# west -> 1
# coast -> 1
# burger -> 2
# chain -> 1
# together -> 1
# simply -> 1
# experience -> 2
# most -> 6
# shameful -> 1
# question -> 4
# fast -> 2
# cause -> 14
# fries -> 1
# eating -> 3
# car -> 5
# bet -> 1
# fat -> 1
# pile -> 1
# sting -> 1
# am -> 11
# living -> 2
# bag -> 1
# tray -> 1
# falls -> 1
# lap -> 1
# pick -> 3
# mumbling -> 8
# hot -> 1
# dog -> 1
# french -> 1
# jerk -> 2
# off -> 5
# lonely -> 1
# free -> 4
# milkshake -> 1
# bummin -> 1
# everybody -> 5
# workers -> 1
# making -> 1
# sad -> 1
# retarded -> 2
# anymore -> 3
# remember -> 5
# upset -> 2
# support -> 2
# arguments -> 1
# against -> 1
# shouldn -> 1
# over -> 10
# said -> 36
# were -> 12
# at -> 34
# describe -> 2
# idea -> 2
# or -> 12
# situation -> 4
# friend -> 4
# house -> 6
# back -> 10
# later -> 6
# bags -> 1
# after -> 6
# would -> 28
# ta -> 4
# smart -> 1
# has -> 7
# extra -> 1
# chromosome -> 1
# damn -> 1
# used -> 5
# abuse -> 1
# expression -> 1
# lie -> 1
# remotely -> 1
# sexual -> 1
# time -> 21
# water -> 2
# d -> 17
# balloons -> 1
# clear -> 3
# overtly -> 1
# gay -> 1
# ten -> 6
# guys -> 11
# standing -> 2
# line -> 3
# each -> 1
# them -> 12
# their -> 7
# dick -> 3
# ass -> 3
# front -> 3
# marching -> 1
# take -> 9
# goddamn -> 3
# cruel -> 1
# perfectly -> 1
# acceptable -> 1
# best -> 8
# part -> 5
# word -> 5
# midget -> 1
# before -> 4
# became -> 2
# offensive -> 2
# specific -> 3
# someone -> 5
# great -> 8
# could -> 7
# zoo -> 1
# feed -> 1
# lions -> 1
# happened -> 8
# next -> 7
# child -> 1
# under -> 1
# saying -> 11
# might -> 4
# seat -> 3
# tom -> 4
# still -> 7
# white -> 13
# racial -> 3
# slurs -> 1
# em -> 5
# her -> 12
# rip -> 1
# cracker -> 3
# mick -> 1
# kraut -> 1
# polack -> 1
# frog -> 1
# guinea -> 1
# wop -> 1
# honky -> 6
# fun -> 3
# those -> 10
# exactly -> 2
# cares -> 1
# call -> 5
# italian -> 1
# tomorrow -> 4
# care -> 5
# historically -> 1
# disenfranchised -> 1
# group -> 2
# slur -> 1
# itself -> 1
# reason -> 2
# truly -> 1
# racist -> 2
# latched -> 1
# onto -> 1
# act -> 2
# run -> 2
# okay -> 12
# believe -> 5
# watch -> 8
# news -> 2
# fight -> 5
# find -> 2
# hillbilly -> 1
# called -> 4
# pass -> 1
# hysterically -> 1
# stabbed -> 1
# pay -> 2
# which -> 9
# terrible -> 2
# watched -> 4
# every -> 10
# fights -> 2
# weird -> 4
# quality -> 1
# kinda -> 1
# hand -> 3
# jobs -> 3
# kiss -> 1
# had -> 12
# shot -> 5
# philadelphia -> 1
# walking -> 7
# park -> 10
# middle -> 1
# beautiful -> 3
# philly -> 1
# as -> 17
# yells -> 1
# across -> 2
# black -> 9
# calls -> 2
# mumbles -> 8
# hear -> 6
# god -> 6
# another -> 5
# lived -> 2
# bushes -> 2
# popped -> 1
# bush -> 1
# only -> 6
# own -> 4
# movie -> 1
# honey -> 1
# badger -> 1
# sprinted -> 1
# tackled -> 1
# instinctively -> 2
# went -> 8
# took -> 2
# second -> 3
# realize -> 1
# other -> 10
# turned -> 1
# killed -> 3
# record -> 1
# such -> 2
# thing -> 9
# loyalty -> 2
# obvious -> 1
# torches -> 1
# having -> 5
# jealous -> 1
# races -> 1
# asians -> 1
# sure -> 3
# dangerous -> 1
# involve -> 1
# myself -> 4
# account -> 1
# being -> 8
# race -> 1
# core -> 1
# whatever -> 3
# help -> 1
# murdered -> 1
# pictures -> 1
# beaten -> 1
# upload -> 1
# deadhonky -> 1
# fantastic -> 2
# republic -> 1
# city -> 3
# love -> 8
# already -> 1
# taken -> 1
# granted -> 1
# lax -> 1
# weed -> 10
# laws -> 3
# forget -> 5
# struggle -> 1
# traumatized -> 4
# by -> 12
# acknowledge -> 1
# upbringing -> 1
# four -> 4
# old -> 12
# nation -> 2
# bought -> 5
# last -> 7
# week -> 2
# dude -> 6
# gave -> 1
# put -> 5
# tape -> 1
# forehead -> 1
# gives -> 1
# these -> 7
# horrific -> 1
# imprisoned -> 1
# highlights -> 2
# absurdity -> 1
# illegal -> 1
# crazy -> 3
# generation -> 1
# stories -> 3
# zero -> 1
# percent -> 3
# chance -> 1
# understand -> 3
# trying -> 5
# kid -> 8
# pigeons -> 1
# deliver -> 1
# son -> 7
# age -> 1
# almost -> 1
# fire -> 1
# sell -> 2
# daddy -> 1
# cars -> 2
# chill -> 1
# round -> 1
# trips -> 1
# kind -> 4
# moving -> 1
# twenty -> 1
# dollars -> 1
# worth -> 1
# marijuana -> 4
# major -> 1
# trailer -> 5
# solo -> 1
# terrifying -> 1
# housing -> 1
# exists -> 1
# kick -> 2
# walked -> 4
# sack -> 1
# need -> 5
# sole -> 1
# responsibility -> 3
# tried -> 3
# play -> 2
# cool -> 4
# stay -> 1
# shotgun -> 1
# anybody -> 6
# blast -> 1
# inside -> 3
# paralysis -> 1
# pow -> 1
# imitates -> 3
# explosion -> 2
# stopped -> 1
# door -> 3
# shoot -> 2
# description -> 1
# agree -> 1
# terms -> 1
# height -> 1
# mom -> 3
# agrees -> 1
# fine -> 3
# parents -> 2
# dad -> 18
# vietnam -> 3
# vet -> 1
# stranger -> 2
# father -> 2
# movies -> 3
# war -> 1
# kill -> 5
# few -> 4
# lieutenant -> 1
# charge -> 1
# work -> 2
# threw -> 3
# grenades -> 1
# pieces -> 1
# year -> 5
# feeling -> 3
# killing -> 2
# talked -> 1
# christmas -> 2
# stood -> 1
# sister -> 1
# brought -> 2
# she -> 38
# smoke -> 1
# genuinely -> 1
# curious -> 1
# party -> 1
# somebody -> 5
# pulled -> 1
# cigarette -> 1
# story -> 5
# nerd -> 1
# ones -> 2
# viet -> 1
# cong -> 1
# marines -> 1
# found -> 2
# picked -> 2
# throat -> 1
# ground -> 1
# face -> 6
# between -> 2
# jesus -> 3
# bro -> 1
# woodpecker -> 5
# make -> 5
# sense -> 3
# woodpeckers -> 1
# damage -> 1
# paid -> 2
# patch -> 1
# month -> 1
# returned -> 1
# woke -> 2
# teenage -> 1
# saturday -> 2
# morning -> 3
# picture -> 3
# dead -> 3
# asleep -> 2
# whispering -> 1
# ear -> 2
# potent -> 1
# breath -> 1
# whispers -> 1
# figure -> 4
# rifle -> 1
# landed -> 1
# bigger -> 1
# close -> 3
# big -> 5
# red -> 1
# feathers -> 1
# distinct -> 1
# features -> 1
# blown -> 1
# bagged -> 1
# girlfriend -> 2
# telling -> 4
# family -> 2
# lunch -> 1
# mention -> 1
# ran -> 1
# wildlife -> 1
# conservation -> 1
# center -> 1
# heard -> 3
# forks -> 1
# drop -> 2
# endangered -> 1
# murmurs -> 1
# made -> 2
# feel -> 10
# knowing -> 1
# enemy -> 1
# loved -> 2
# birds -> 1
# extinct -> 1
# obviously -> 1
# tour -> 1
# long -> 2
# meet -> 4
# sometimes -> 4
# shows -> 5
# roll -> 1
# dice -> 1
# meeting -> 1
# lunatics -> 1
# met -> 3
# show -> 7
# shaking -> 1
# hands -> 3
# hi -> 2
# originally -> 1
# born -> 3
# cincinnati -> 3
# moved -> 1
# around -> 7
# decipher -> 1
# southern -> 3
# accent -> 11
# lafayette -> 1
# louisiana -> 2
# miles -> 1
# south -> 1
# bunch -> 2
# seguras -> 1
# realized -> 2
# whole -> 2
# population -> 1
# cajun -> 1
# amongst -> 1
# rights -> 1
# audacity -> 1
# redbox -> 1
# moments -> 5
# declare -> 1
# cartoon -> 1
# character -> 1
# building -> 5
# wall -> 4
# state -> 1
# minds -> 1
# swamp -> 1
# miss -> 1
# shrimp -> 1
# contribution -> 1
# gator -> 1
# inbreds -> 2
# checked -> 1
# hotels -> 2
# half -> 1
# dozen -> 1
# exaggerating -> 1
# hotel -> 3
# begins -> 1
# usually -> 1
# standard -> 1
# desk -> 1
# japanese -> 3
# hundred -> 1
# stop -> 8
# gruff -> 2
# voice -> 2
# segura -> 5
# sounds -> 2
# smith -> 1
# rude -> 3
# important -> 6
# sushi -> 1
# chef -> 1
# accountant -> 1
# dash -> 1
# matters -> 1
# spanish -> 16
# speak -> 9
# failed -> 1
# social -> 1
# studies -> 1
# geography -> 1
# head -> 5
# feels -> 2
# bad -> 4
# mexico -> 1
# asian -> 6
# pants -> 1
# expect -> 1
# dim -> 1
# perfect -> 2
# credit -> 1
# mother -> 4
# peruvian -> 1
# english -> 2
# wasn -> 2
# spoke -> 1
# different -> 2
# reactions -> 1
# either -> 2
# completely -> 1
# incredulous -> 1
# coming -> 2
# mouth -> 2
# piss -> 3
# aramaic -> 1
# supposed -> 2
# outta -> 1
# reaction -> 1
# high -> 2
# played -> 1
# football -> 5
# school -> 5
# broncos -> 1
# aren -> 2
# giving -> 1
# capital -> 1
# mierda -> 1
# grew -> 1
# household -> 1
# listened -> 1
# music -> 3
# point -> 3
# listen -> 4
# influences -> 1
# become -> 1
# singer -> 2
# named -> 1
# juan -> 1
# luis -> 1
# guerra -> 1
# dominican -> 1
# sing -> 2
# songs -> 2
# titles -> 1
# si -> 1
# tu -> 1
# te -> 1
# lyrics -> 1
# heart -> 1
# balance -> 1
# todd -> 1
# shaw -> 1
# stage -> 1
# short -> 1
# blow -> 1
# job -> 1
# forth -> 1
# songwriters -> 1
# singing -> 1
# bust -> 1
# left -> 2
# nut -> 2
# jaw -> 1
# sperm -> 1
# cheeks -> 1
# ya -> 1
# grunting -> 2
# sorry -> 2
# way -> 8
# satisfying -> 1
# letting -> 1
# elevator -> 3
# earlier -> 1
# warm -> 1
# rush -> 1
# body -> 4
# felt -> 2
# hugged -> 1
# outside -> 2
# taste -> 2
# power -> 3
# everyday -> 1
# lives -> 2
# alone -> 1
# lord -> 1
# shaft -> 1
# decide -> 1
# king -> 2
# drawbridge -> 1
# opens -> 1
# nervous -> 1
# energy -> 1
# lady -> 7
# works -> 1
# buttons -> 1
# equal -> 1
# parking -> 3
# matter -> 1
# drive -> 3
# space -> 1
# yours -> 1
# looking -> 3
# moment -> 3
# mall -> 1
# shopping -> 1
# false -> 1
# waiting -> 1
# brake -> 3
# light -> 1
# blinker -> 2
# marshals -> 1
# lights -> 1
# appear -> 1
# starting -> 1
# release -> 1
# tension -> 1
# rising -> 1
# snap -> 1
# hour -> 1
# philosophical -> 1
# timing -> 2
# wiping -> 1
# professional -> 1
# athlete -> 1
# autograph -> 2
# answer -> 1
# thankfully -> 2
# friends -> 4
# favorite -> 3
# adult -> 1
# buddies -> 2
# bengals -> 1
# fan -> 1
# tough -> 2
# game -> 3
# decides -> 2
# tunnel -> 2
# players -> 1
# autographs -> 1
# wondering -> 2
# boy -> 3
# grown -> 2
# stadium -> 1
# keep -> 3
# imagine -> 3
# heroes -> 1
# adam -> 1
# pacman -> 4
# jones -> 1
# locker -> 1
# follow -> 1
# strip -> 1
# club -> 1
# vibe -> 1
# approachable -> 1
# whoo -> 1
# biggest -> 2
# sign -> 5
# pac -> 2
# shitting -> 1
# knows -> 1
# walks -> 1
# loves -> 2
# looked -> 5
# motherfucker -> 5
# appreciate -> 8
# end -> 1
# juxtaposition -> 1
# angrily -> 1
# incorporate -> 1
# airport -> 1
# bar -> 1
# getting -> 5
# flight -> 1
# bartender -> 1
# recognized -> 1
# sent -> 2
# hell -> 2
# asshole -> 4
# working -> 1
# woman -> 7
# allowed -> 3
# came -> 3
# giggles -> 3
# impression -> 2
# funny -> 7
# grunts -> 4
# thanks -> 3
# spot -> 1
# super -> 2
# horny -> 2
# freshman -> 2
# college -> 2
# alarming -> 1
# students -> 1
# administrator -> 1
# narc -> 1
# birth -> 1
# jump -> 2
# street -> 1
# alcohol -> 1
# entire -> 5
# dorm -> 2
# three -> 5
# challenge -> 1
# liquor -> 1
# stores -> 1
# hello -> 2
# sir -> 1
# stock -> 1
# market -> 1
# booze -> 2
# pornography -> 1
# takes -> 1
# buffering -> 1
# truth -> 2
# late -> 2
# porn -> 4
# ah -> 4
# kidding -> 1
# use -> 1
# mind -> 1
# buying -> 2
# couple -> 1
# freshmen -> 1
# dudes -> 1
# massive -> 1
# orders -> 1
# cash -> 1
# list -> 2
# cocks -> 1
# asses -> 1
# feet -> 1
# psychopath -> 1
# store -> 4
# grocery -> 1
# fakes -> 1
# laughter -> 1
# outrageous -> 1
# amounts -> 1
# owner -> 1
# customer -> 1
# sends -> 1
# address -> 1
# wearing -> 2
# overalls -> 1
# international -> 1
# uniform -> 1
# behind -> 3
# counter -> 1
# looks -> 2
# sees -> 2
# words -> 1
# fetish -> 1
# full -> 1
# bladder -> 1
# waste -> 1
# among -> 1
# toys -> 1
# booth -> 2
# vip -> 1
# notice -> 1
# hole -> 4
# stick -> 3
# finger -> 5
# prick -> 1
# clicks -> 1
# tongue -> 1
# side -> 1
# dumb -> 1
# girl -> 2
# junior -> 1
# pool -> 1
# diarrhea -> 1
# forming -> 1
# fear -> 1
# shooting -> 1
# spine -> 1
# certain -> 1
# kidnapped -> 1
# raped -> 1
# dynasty -> 1
# willing -> 1
# unmarked -> 1
# polish -> 1
# savages -> 1
# men -> 3
# remind -> 1
# women -> 2
# pigs -> 1
# drinks -> 1
# answered -> 1
# rough -> 1
# chin -> 1
# pig -> 2
# however -> 1
# permission -> 1
# unlimited -> 1
# needs -> 1
# nudge -> 1
# both -> 2
# ways -> 1
# fascinating -> 1
# doggie -> 1
# barking -> 1
# older -> 1
# balls -> 3
# vision -> 7
# starts -> 3
# decline -> 1
# especially -> 2
# excellent -> 1
# charts -> 1
# hanging -> 1
# blocks -> 1
# squint -> 1
# death -> 1
# accept -> 1
# denial -> 2
# dmv -> 2
# renew -> 1
# license -> 1
# casually -> 1
# read -> 2
# arrogant -> 1
# pfft -> 2
# check -> 1
# x -> 1
# g -> 1
# l -> 1
# seven -> 1
# symbol -> 1
# chuckles -> 1
# los -> 1
# angeles -> 1
# panic -> 1
# straight -> 1
# doctor -> 3
# abusive -> 1
# seeing -> 1
# decade -> 1
# office -> 2
# test -> 1
# prostate -> 2
# eyes -> 4
# sorbet -> 1
# flavor -> 1
# naked -> 1
# fetal -> 1
# position -> 1
# lubes -> 1
# ton -> 1
# lube -> 1
# success -> 1
# bit -> 3
# pressure -> 1
# moderately -> 1
# promise -> 1
# appreciation -> 1
# checks -> 1
# rather -> 1
# aggressively -> 1
# add -> 1
# opinion -> 1
# laugh -> 3
# clamping -> 1
# until -> 2
# exam -> 1
# jokes -> 1
# tested -> 2
# washed -> 1
# latent -> 1
# quote -> 1
# sucked -> 1
# explain -> 1
# fighting -> 1
# young -> 1
# uh -> 1
# skin -> 1
# interesting -> 1
# putting -> 1
# hair -> 1
# fell -> 1
# physical -> 2
# flaws -> 2
# disabilities -> 1
# quilt -> 1
# debate -> 1
# examples -> 1
# foreign -> 4
# syndrome -> 3
# real -> 3
# trauma -> 1
# native -> 1
# language -> 1
# defy -> 1
# interviews -> 1
# yourself -> 1
# farmer -> 1
# alabama -> 1
# normally -> 1
# hits -> 1
# eh -> 1
# tractor -> 1
# case -> 1
# uk -> 2
# british -> 5
# town -> 1
# accident -> 1
# chinese -> 3
# humor -> 1
# whiffle -> 1
# says -> 1
# conversation -> 1
# hard -> 2
# without -> 2
# squinting -> 1
# uncomfortable -> 1
# mocking -> 1
# happens -> 2
# cup -> 1
# tea -> 1
# milk -> 1
# biscuit -> 1
# nice -> 2
# wants -> 1
# tits -> 1
# tussle -> 1
# persistent -> 1
# genital -> 1
# arousal -> 1
# disorder -> 1
# fancy -> 1
# orgasms -> 1
# seconds -> 1
# appropriate -> 1
# shirt -> 3
# wear -> 2
# orange -> 2
# bring -> 2
# sugar -> 1
# suffer -> 1
# afflictions -> 1
# rare -> 1
# passing -> 1
# cheap -> 1
# board -> 1
# reliable -> 1
# tourette -> 2
# fifth -> 1
# grade -> 1
# new -> 6
# wednesday -> 1
# catholic -> 1
# wednesdays -> 1
# mass -> 1
# student -> 1
# church -> 1
# priest -> 1
# service -> 1
# row -> 1
# batted -> 1
# eye -> 2
# reading -> 1
# bible -> 1
# lick -> 1
# stroke -> 1
# tears -> 1
# running -> 1
# finally -> 1
# able -> 1
# gets -> 1
# greatest -> 2
# gift -> 1
# bestowed -> 1
# upon -> 1
# substitute -> 1
# teacher -> 1
# warn -> 1
# imagination -> 1
# serving -> 1
# correctly -> 1
# glorious -> 1
# break -> 1
# spirit -> 1
# poor -> 1
# substitutes -> 1
# class -> 2
# somehow -> 1
# chapter -> 1
# ticks -> 1
# build -> 1
# start -> 1
# small -> 1
# gasps -> 1
# markers -> 1
# paint -> 1
# bitch -> 2
# painting -> 1
# marker -> 1
# happening -> 2
# kevin -> 1
# crying -> 1
# herself -> 1
# teaching -> 1
# trust -> 1
# course -> 1
# easy -> 2
# easier -> 1
# seriously -> 1
# abandon -> 1
# inherently -> 1
# harder -> 1
# beginning -> 1
# complain -> 1
# cries -> 3
# bawl -> 1
# cute -> 3
# strangle -> 1
# below -> 1
# babies -> 2
# cuter -> 1
# bunnies -> 1
# puppies -> 1
# combined -> 1
# throw -> 1
# baby -> 2
# exchange -> 1
# rate -> 1
# please -> 1
# collectively -> 1
# society -> 1
# pushing -> 1
# myth -> 1
# selfless -> 3
# selfish -> 3
# necessary -> 1
# fall -> 1
# miniature -> 1
# version -> 1
# parts -> 5
# mostly -> 1
# fresh -> 1
# kissing -> 1
# populating -> 1
# martin -> 1
# luther -> 1
# crab -> 1
# legs -> 1
# sale -> 1
# costco -> 1
# sunday -> 1
# y -> 1
# parenthood -> 1
# sleep -> 2
# till -> 1
# noon -> 1
# sip -> 1
# live -> 1
# masturbating -> 2
# parent -> 2
# forward -> 1
# sex -> 1
# treat -> 1
# dogs -> 1
# taunt -> 1
# grab -> 1
# exciting -> 1
# shoes -> 2
# portland -> 1
# oregon -> 1
# afterwards -> 1
# noticed -> 1
# nikes -> 1
# nike -> 6
# headquarters -> 1
# shop -> 3
# employee -> 1
# warehouse -> 1
# product -> 1
# imaginable -> 1
# rent -> 1
# empty -> 1
# system -> 1
# flagged -> 1
# excuse -> 1
# entertainer -> 1
# influence -> 1
# fucked -> 1
# entertainment -> 1
# answers -> 1
# calling -> 1
# regroup -> 1
# adidas -> 1
# survive -> 1
# purchases -> 1
# company -> 1
# told -> 1
# york -> 1
# executive -> 1
# cell -> 1
# night -> 2
# diaper -> 5
# insult -> 3
# fingertips -> 1
# utilizing -> 1
# enough -> 1
# lexicon -> 1
# ultimate -> 1
# serious -> 1
# rappers -> 1
# videos -> 1
# president -> 1
# country -> 1
# appealing -> 1
# key -> 1
# secret -> 1
# physically -> 1
# horror -> 1
# shits -> 1
# closed -> 1
# often -> 1
# guessing -> 1
# twice -> 1
# cancun -> 1
# thai -> 1
# restaurant -> 1
# handle -> 1
# single -> 1
# makes -> 1
# contact -> 1
# pushes -> 1
# stares -> 1
# ugh -> 1
# nasty -> 1
# once -> 1
# cleaning -> 1

# %%
# Sort it so you get the most commonly used words on top
sorted_dict = sorted(filtered_word_freq, key=filtered_word_freq.get, reverse=True)
type(sorted_dict)
sorted_dict
# Out:
# ['i',
#  'you',
#  'audience',
#  'laughs',
#  'and',
#  'a',
#  's',
#  'that',
#  'like',
#  'the',
#  'it',
#  'to',
#  'he',
#  're',
#  't',
#  'of',
#  'in',
#  'go',
#  'my',
#  'm',
#  'goes',
#  'is',
#  'don',
#  'know',
#  'what',
#  'was',
#  'they',
#  'me',
#  'are',
#  'your',
#  'we',
#  'so',
#  'this',
#  'if',
#  'can',
#  'not',
#  'do',
#  'up',
#  'be',
#  'll',
#  'just',
#  'but',
#  'for',
#  'get',
#  'people',
#  'all',
#  'have',
#  'now',
#  'no',
#  'out',
#  'then',
#  'on',
#  'want',
#  'about',
#  'she',
#  'there',
#  'why',
#  'fuck',
#  'fuckin',
#  'said',
#  'right',
#  'say',
#  'at',
#  'see',
#  'guy',
#  'na',
#  'when',
#  'shit',
#  'think',
#  'gon',
#  'yeah',
#  'would',
#  'how',
#  'with',
#  'tell',
#  'one',
#  'him',
#  'did',
#  'an',
#  'got',
#  've',
#  'here',
#  'his',
#  'some',
#  'man',
#  'time',
#  'never',
#  'clapping',
#  'from',
#  'cheering',
#  'dad',
#  'oh',
#  'look',
#  'more',
#  'd',
#  'as',
#  'well',
#  'years',
#  'should',
#  'been',
#  'who',
#  'spanish',
#  'ever',
#  'will',
#  'give',
#  'our',
#  'lot',
#  'through',
#  'cause',
#  'life',
#  'let',
#  'day',
#  'didn',
#  'white',
#  'where',
#  'mean',
#  'were',
#  'or',
#  'them',
#  'her',
#  'okay',
#  'had',
#  'by',
#  'old',
#  'first',
#  'into',
#  'really',
#  'something',
#  'come',
#  'going',
#  'am',
#  'guys',
#  'saying',
#  'accent',
#  'us',
#  'ask',
#  'than',
#  'over',
#  'back',
#  'those',
#  'every',
#  'park',
#  'other',
#  'weed',
#  'feel',
#  'good',
#  'laughing',
#  'very',
#  'even',
#  'hey',
#  'take',
#  'which',
#  'black',
#  'thing',
#  'speak',
#  'thought',
#  'any',
#  'leave',
#  'sit',
#  'same',
#  'saw',
#  'doesn',
#  'bed',
#  'little',
#  'two',
#  'weight',
#  'doing',
#  'mumbling',
#  'best',
#  'great',
#  'happened',
#  'watch',
#  'mumbles',
#  'went',
#  'being',
#  'love',
#  'kid',
#  'stop',
#  'way',
#  'appreciate',
#  'much',
#  'home',
#  'too',
#  'away',
#  'isn',
#  'talking',
#  'try',
#  'because',
#  'eat',
#  'has',
#  'their',
#  'could',
#  'next',
#  'still',
#  'walking',
#  'last',
#  'these',
#  'son',
#  'show',
#  'around',
#  'lady',
#  'woman',
#  'funny',
#  'vision',
#  'walk',
#  'place',
#  'does',
#  'change',
#  'means',
#  'bah',
#  'wait',
#  'name',
#  'better',
#  'awesome',
#  'many',
#  'nobody',
#  'most',
#  'house',
#  'later',
#  'after',
#  'ten',
#  'honky',
#  'hear',
#  'god',
#  'only',
#  'dude',
#  'anybody',
#  'face',
#  'important',
#  'asian',
#  'new',
#  'nike',
#  'thank',
#  'meaning',
#  'always',
#  'pretty',
#  'anything',
#  'comes',
#  'down',
#  'sitting',
#  'speaking',
#  'person',
#  'maybe',
#  'probably',
#  'food',
#  'today',
#  'car',
#  'off',
#  'everybody',
#  'remember',
#  'used',
#  'part',
#  'word',
#  'someone',
#  'em',
#  'call',
#  'care',
#  'believe',
#  'fight',
#  'shot',
#  'another',
#  'having',
#  'forget',
#  'bought',
#  'put',
#  'trying',
#  'trailer',
#  'need',
#  'kill',
#  'year',
#  'somebody',
#  'story',
#  'woodpecker',
#  'make',
#  'big',
#  'shows',
#  'moments',
#  'building',
#  'segura',
#  'head',
#  'football',
#  'school',
#  'sign',
#  'looked',
#  'motherfucker',
#  'getting',
#  'entire',
#  'three',
#  'finger',
#  'british',
#  'parts',
#  'diaper',
#  'whoa',
#  'amazing',
#  'whooping',
#  'room',
#  'again',
#  'number',
#  'pull',
#  'suck',
#  'tired',
#  'rest',
#  'recently',
#  'yes',
#  'talk',
#  'lose',
#  'hit',
#  'asked',
#  'else',
#  'question',
#  'free',
#  'situation',
#  'friend',
#  'ta',
#  'before',
#  'might',
#  'tom',
#  'tomorrow',
#  'called',
#  'watched',
#  'weird',
#  'own',
#  'myself',
#  'traumatized',
#  'four',
#  'kind',
#  'marijuana',
#  'walked',
#  'cool',
#  'few',
#  'figure',
#  'telling',
#  'meet',
#  'sometimes',
#  'wall',
#  'bad',
#  'mother',
#  'listen',
#  'body',
#  'friends',
#  'pacman',
#  'asshole',
#  'grunts',
#  'porn',
#  'ah',
#  'store',
#  'hole',
#  'eyes',
#  'foreign',
#  'holy',
#  'denver',
#  'wish',
#  'hope',
#  'also',
#  'excited',
#  'buy',
#  'hold',
#  'haven',
#  'done',
#  'open',
#  'lost',
#  'loss',
#  'seen',
#  'public',
#  'times',
#  'message',
#  'starbucks',
#  'wanted',
#  'honest',
#  'eating',
#  'pick',
#  'anymore',
#  'clear',
#  'line',
#  'dick',
#  'ass',
#  'front',
#  'goddamn',
#  'specific',
#  'seat',
#  'racial',
#  'cracker',
#  'fun',
#  'hand',
#  'jobs',
#  'beautiful',
#  'second',
#  'killed',
#  'sure',
#  'whatever',
#  'city',
#  'laws',
#  'crazy',
#  'stories',
#  'percent',
#  'understand',
#  'responsibility',
#  'tried',
#  'inside',
#  'imitates',
#  'door',
#  'mom',
#  'fine',
#  'vietnam',
#  'movies',
#  'threw',
#  'feeling',
#  'jesus',
#  'sense',
#  'morning',
#  'picture',
#  'dead',
#  'close',
#  'heard',
#  'met',
#  'hands',
#  'born',
#  'cincinnati',
#  'southern',
#  'hotel',
#  'japanese',
#  'rude',
#  'piss',
#  'music',
#  'point',
#  'elevator',
#  'power',
#  'parking',
#  'drive',
#  'looking',
#  'moment',
#  'brake',
#  'favorite',
#  'game',
#  'boy',
#  'keep',
#  'imagine',
#  'allowed',
#  'came',
#  'giggles',
#  'thanks',
#  'behind',
#  'stick',
#  'men',
#  'balls',
#  'starts',
#  'doctor',
#  'bit',
#  'laugh',
#  'syndrome',
#  'real',
#  'chinese',
#  'shirt',
#  'cries',
#  'cute',
#  'selfless',
#  'selfish',
#  'shop',
#  'insult',
#  'personal',
#  'wrap',
#  'actually',
#  'whistling',
#  'luckily',
#  'five',
#  'homes',
#  'order',
#  'phone',
#  'blows',
#  'raspberry',
#  'everyone',
#  'indicator',
#  'soon',
#  'commercials',
#  'beds',
#  'air',
#  'basically',
#  'guess',
#  'piece',
#  'lay',
#  'wake',
#  'world',
#  'pounds',
#  'contest',
#  'sucks',
#  'messages',
#  'coach',
#  'absolutely',
#  'hate',
#  'ready',
#  'true',
#  'started',
#  'burger',
#  'experience',
#  'fast',
#  'living',
#  'jerk',
#  'retarded',
#  'upset',
#  'support',
#  'describe',
#  'idea',
#  'water',
#  'standing',
#  'became',
#  'offensive',
#  'exactly',
#  'group',
#  'reason',
#  'racist',
#  'act',
#  'run',
#  'news',
#  'find',
#  'pay',
#  'terrible',
#  'fights',
#  'across',
#  'calls',
#  'lived',
#  'bushes',
#  'instinctively',
#  'took',
#  'such',
#  'loyalty',
#  'fantastic',
#  'nation',
#  'week',
#  'highlights',
#  'sell',
#  'cars',
#  'kick',
#  'play',
#  'explosion',
#  'shoot',
#  'parents',
#  'stranger',
#  'father',
#  'work',
#  'killing',
#  'christmas',
#  'brought',
#  'ones',
#  'found',
#  'picked',
#  'between',
#  'paid',
#  'woke',
#  'saturday',
#  'asleep',
#  'ear',
#  'girlfriend',
#  'family',
#  'drop',
#  'made',
#  'loved',
#  'long',
#  'hi',
#  'louisiana',
#  'bunch',
#  'realized',
#  'whole',
#  'inbreds',
#  'hotels',
#  'gruff',
#  'voice',
#  'sounds',
#  'feels',
#  'perfect',
#  'english',
#  'wasn',
#  'different',
#  'either',
#  'coming',
#  'mouth',
#  'supposed',
#  'high',
#  'aren',
#  'singer',
#  'sing',
#  'songs',
#  'left',
#  'nut',
#  'grunting',
#  'sorry',
#  'felt',
#  'outside',
#  'taste',
#  'lives',
#  'king',
#  'blinker',
#  'timing',
#  'autograph',
#  'thankfully',
#  'buddies',
#  'tough',
#  'decides',
#  'tunnel',
#  'wondering',
#  'grown',
#  'biggest',
#  'pac',
#  'loves',
#  'sent',
#  'hell',
#  'impression',
#  'super',
#  'horny',
#  'freshman',
#  'college',
#  'jump',
#  'dorm',
#  'hello',
#  'booze',
#  'truth',
#  'late',
#  'buying',
#  'list',
#  'wearing',
#  'looks',
#  'sees',
#  'booth',
#  'girl',
#  'women',
#  'pig',
#  'both',
#  'especially',
#  'denial',
#  'dmv',
#  'read',
#  'pfft',
#  'office',
#  'prostate',
#  'until',
#  'tested',
#  'physical',
#  'flaws',
#  'uk',
#  'hard',
#  'without',
#  'happens',
#  'nice',
#  'wear',
#  'orange',
#  'bring',
#  'tourette',
#  'eye',
#  'greatest',
#  'class',
#  'bitch',
#  'happening',
#  'easy',
#  'babies',
#  'baby',
#  'sleep',
#  'masturbating',
#  'parent',
#  'shoes',
#  'night',
#  'offense',
#  'literally',
#  'whenever',
#  'philosophizing',
#  'leaving',
#  'indicators',
#  'paying',
#  'attention',
#  'process',
#  'things',
#  'couch',
#  'bananas',
#  'hammers',
#  'eagle',
#  'amazon',
#  'insane',
#  'device',
#  'watching',
#  'tv',
#  'endless',
#  'advertise',
#  'snoring',
#  'sleeping',
#  'hours',
#  'turd',
#  'mechanical',
#  'arm',
#  'wan',
#  'decent',
#  'amount',
#  'fattest',
#  'earth',
#  'may',
#  'brent',
#  'crystals',
#  'beat',
#  'thinking',
#  'platform',
#  'inspired',
#  'mirror',
#  'cry',
#  'send',
#  'grand',
#  'scale',
#  'helping',
#  'national',
#  'training',
#  'campaign',
#  'trick',
#  'ordering',
#  'beverage',
#  'lead',
#  'greet',
#  'welcome',
#  'sausage',
#  'respect',
#  'shame',
#  'west',
#  'coast',
#  'chain',
#  'together',
#  'simply',
#  'shameful',
#  'fries',
#  'bet',
#  'fat',
#  'pile',
#  'sting',
#  'bag',
#  'tray',
#  'falls',
#  'lap',
#  'hot',
#  'dog',
#  'french',
#  'lonely',
#  'milkshake',
#  'bummin',
#  'workers',
#  'making',
#  'sad',
#  'arguments',
#  'against',
#  'shouldn',
#  'bags',
#  'smart',
#  'extra',
#  'chromosome',
#  'damn',
#  'abuse',
#  'expression',
#  'lie',
#  'remotely',
#  'sexual',
#  'balloons',
#  'overtly',
#  'gay',
#  'each',
#  'marching',
#  'cruel',
#  'perfectly',
#  'acceptable',
#  'midget',
#  'zoo',
#  'feed',
#  'lions',
#  'child',
#  'under',
#  'slurs',
#  'rip',
#  'mick',
#  'kraut',
#  'polack',
#  'frog',
#  'guinea',
#  'wop',
#  'cares',
#  'italian',
#  'historically',
#  'disenfranchised',
#  'slur',
#  'itself',
#  'truly',
#  'latched',
#  'onto',
#  'hillbilly',
#  'pass',
#  'hysterically',
#  'stabbed',
#  'quality',
#  'kinda',
#  'kiss',
#  'philadelphia',
#  'middle',
#  'philly',
#  'yells',
#  'popped',
#  'bush',
#  'movie',
#  'honey',
#  'badger',
#  'sprinted',
#  'tackled',
#  'realize',
#  'turned',
#  'record',
#  'obvious',
#  'torches',
#  'jealous',
#  'races',
#  'asians',
#  'dangerous',
#  'involve',
#  'account',
#  'race',
#  'core',
#  'help',
#  'murdered',
#  'pictures',
#  'beaten',
#  'upload',
#  'deadhonky',
#  'republic',
#  'already',
#  'taken',
#  'granted',
#  'lax',
#  'struggle',
#  'acknowledge',
#  'upbringing',
#  'gave',
#  'tape',
#  'forehead',
#  'gives',
#  'horrific',
#  'imprisoned',
#  'absurdity',
#  'illegal',
#  'generation',
#  'zero',
#  'chance',
#  'pigeons',
#  'deliver',
#  'age',
#  'almost',
#  'fire',
#  'daddy',
#  'chill',
#  'round',
#  'trips',
#  'moving',
#  'twenty',
#  'dollars',
#  'worth',
#  'major',
#  'solo',
#  'terrifying',
#  'housing',
#  'exists',
#  'sack',
#  'sole',
#  'stay',
#  'shotgun',
#  'blast',
#  'paralysis',
#  'pow',
#  'stopped',
#  'description',
#  'agree',
#  'terms',
#  'height',
#  'agrees',
#  'vet',
#  'war',
#  'lieutenant',
#  'charge',
#  'grenades',
#  'pieces',
#  'talked',
#  'stood',
#  'sister',
#  'smoke',
#  'genuinely',
#  'curious',
#  'party',
#  'pulled',
#  'cigarette',
#  'nerd',
#  'viet',
#  'cong',
#  'marines',
#  'throat',
#  'ground',
#  'bro',
#  'woodpeckers',
#  'damage',
#  'patch',
#  'month',
#  'returned',
#  'teenage',
#  'whispering',
#  'potent',
#  'breath',
#  'whispers',
#  'rifle',
#  'landed',
#  'bigger',
#  'red',
#  'feathers',
#  'distinct',
#  'features',
#  'blown',
#  'bagged',
#  'lunch',
#  'mention',
#  'ran',
#  'wildlife',
#  'conservation',
#  'center',
#  'forks',
#  'endangered',
#  'murmurs',
#  'knowing',
#  'enemy',
#  'birds',
#  'extinct',
#  'obviously',
#  'tour',
#  'roll',
#  'dice',
#  'meeting',
#  'lunatics',
#  'shaking',
#  'originally',
#  'moved',
#  'decipher',
#  'lafayette',
#  'miles',
#  'south',
#  'seguras',
#  'population',
#  'cajun',
#  'amongst',
#  'rights',
#  'audacity',
#  'redbox',
#  'declare',
#  'cartoon',
#  'character',
#  'state',
#  'minds',
#  'swamp',
#  'miss',
#  'shrimp',
#  'contribution',
#  'gator',
#  'checked',
#  'half',
#  'dozen',
#  'exaggerating',
#  'begins',
#  'usually',
#  'standard',
#  'desk',
#  'hundred',
#  'smith',
#  'sushi',
#  'chef',
#  'accountant',
#  'dash',
#  'matters',
#  'failed',
#  'social',
#  'studies',
#  'geography',
#  'mexico',
#  'pants',
#  'expect',
#  'dim',
#  'credit',
#  'peruvian',
#  'spoke',
#  'reactions',
#  'completely',
#  'incredulous',
#  'aramaic',
#  'outta',
#  'reaction',
#  'played',
#  'broncos',
#  'giving',
#  'capital',
#  'mierda',
#  'grew',
#  'household',
#  'listened',
#  'influences',
#  'become',
#  'named',
#  'juan',
#  'luis',
#  ...]

# %%
sorted_values = sorted(filtered_word_freq.values(), reverse=True) # Sort the values
sorted_dict = {}

for i in sorted_values:
    for k in filtered_word_freq.keys():
        if filtered_word_freq[k] == i:
            sorted_dict[k] = filtered_word_freq[k]

# %%
for key, value in sorted_dict.items():
    print(key, '->', value)
# Out:
# i -> 585
# you -> 486
# audience -> 402
# laughs -> 380
# and -> 363
# a -> 224
# s -> 212
# that -> 208
# like -> 207
# the -> 198
# it -> 193
# to -> 161
# he -> 141
# re -> 131
# t -> 129
# of -> 127
# in -> 123
# go -> 107
# my -> 100
# m -> 100
# goes -> 89
# is -> 80
# don -> 80
# know -> 80
# what -> 78
# was -> 75
# they -> 75
# me -> 74
# are -> 72
# your -> 62
# we -> 60
# so -> 58
# this -> 58
# if -> 58
# can -> 57
# not -> 54
# do -> 54
# up -> 51
# be -> 50
# ll -> 48
# just -> 48
# but -> 47
# for -> 46
# get -> 46
# people -> 44
# all -> 44
# have -> 43
# now -> 41
# no -> 41
# out -> 41
# then -> 41
# on -> 40
# want -> 40
# about -> 38
# she -> 38
# there -> 37
# why -> 37
# fuck -> 36
# fuckin -> 36
# said -> 36
# right -> 34
# say -> 34
# at -> 34
# see -> 33
# guy -> 31
# na -> 30
# when -> 30
# shit -> 29
# think -> 29
# gon -> 29
# yeah -> 28
# would -> 28
# how -> 27
# with -> 27
# tell -> 25
# one -> 25
# him -> 25
# did -> 25
# an -> 23
# got -> 23
# ve -> 23
# here -> 23
# his -> 23
# some -> 21
# man -> 21
# time -> 21
# never -> 20
# clapping -> 19
# from -> 18
# cheering -> 18
# dad -> 18
# oh -> 17
# look -> 17
# more -> 17
# d -> 17
# as -> 17
# well -> 16
# years -> 16
# should -> 16
# been -> 16
# who -> 16
# spanish -> 16
# ever -> 15
# will -> 15
# give -> 15
# our -> 14
# lot -> 14
# through -> 14
# cause -> 14
# life -> 13
# let -> 13
# day -> 13
# didn -> 13
# white -> 13
# where -> 12
# mean -> 12
# were -> 12
# or -> 12
# them -> 12
# her -> 12
# okay -> 12
# had -> 12
# by -> 12
# old -> 12
# first -> 11
# into -> 11
# really -> 11
# something -> 11
# come -> 11
# going -> 11
# am -> 11
# guys -> 11
# saying -> 11
# accent -> 11
# us -> 10
# ask -> 10
# than -> 10
# over -> 10
# back -> 10
# those -> 10
# every -> 10
# park -> 10
# other -> 10
# weed -> 10
# feel -> 10
# good -> 9
# laughing -> 9
# very -> 9
# even -> 9
# hey -> 9
# take -> 9
# which -> 9
# black -> 9
# thing -> 9
# speak -> 9
# thought -> 8
# any -> 8
# leave -> 8
# sit -> 8
# same -> 8
# saw -> 8
# doesn -> 8
# bed -> 8
# little -> 8
# two -> 8
# weight -> 8
# doing -> 8
# mumbling -> 8
# best -> 8
# great -> 8
# happened -> 8
# watch -> 8
# mumbles -> 8
# went -> 8
# being -> 8
# love -> 8
# kid -> 8
# stop -> 8
# way -> 8
# appreciate -> 8
# much -> 7
# home -> 7
# too -> 7
# away -> 7
# isn -> 7
# talking -> 7
# try -> 7
# because -> 7
# eat -> 7
# has -> 7
# their -> 7
# could -> 7
# next -> 7
# still -> 7
# walking -> 7
# last -> 7
# these -> 7
# son -> 7
# show -> 7
# around -> 7
# lady -> 7
# woman -> 7
# funny -> 7
# vision -> 7
# walk -> 6
# place -> 6
# does -> 6
# change -> 6
# means -> 6
# bah -> 6
# wait -> 6
# name -> 6
# better -> 6
# awesome -> 6
# many -> 6
# nobody -> 6
# most -> 6
# house -> 6
# later -> 6
# after -> 6
# ten -> 6
# honky -> 6
# hear -> 6
# god -> 6
# only -> 6
# dude -> 6
# anybody -> 6
# face -> 6
# important -> 6
# asian -> 6
# new -> 6
# nike -> 6
# thank -> 5
# meaning -> 5
# always -> 5
# pretty -> 5
# anything -> 5
# comes -> 5
# down -> 5
# sitting -> 5
# speaking -> 5
# person -> 5
# maybe -> 5
# probably -> 5
# food -> 5
# today -> 5
# car -> 5
# off -> 5
# everybody -> 5
# remember -> 5
# used -> 5
# part -> 5
# word -> 5
# someone -> 5
# em -> 5
# call -> 5
# care -> 5
# believe -> 5
# fight -> 5
# shot -> 5
# another -> 5
# having -> 5
# forget -> 5
# bought -> 5
# put -> 5
# trying -> 5
# trailer -> 5
# need -> 5
# kill -> 5
# year -> 5
# somebody -> 5
# story -> 5
# woodpecker -> 5
# make -> 5
# big -> 5
# shows -> 5
# moments -> 5
# building -> 5
# segura -> 5
# head -> 5
# football -> 5
# school -> 5
# sign -> 5
# looked -> 5
# motherfucker -> 5
# getting -> 5
# entire -> 5
# three -> 5
# finger -> 5
# british -> 5
# parts -> 5
# diaper -> 5
# whoa -> 4
# amazing -> 4
# whooping -> 4
# room -> 4
# again -> 4
# number -> 4
# pull -> 4
# suck -> 4
# tired -> 4
# rest -> 4
# recently -> 4
# yes -> 4
# talk -> 4
# lose -> 4
# hit -> 4
# asked -> 4
# else -> 4
# question -> 4
# free -> 4
# situation -> 4
# friend -> 4
# ta -> 4
# before -> 4
# might -> 4
# tom -> 4
# tomorrow -> 4
# called -> 4
# watched -> 4
# weird -> 4
# own -> 4
# myself -> 4
# traumatized -> 4
# four -> 4
# kind -> 4
# marijuana -> 4
# walked -> 4
# cool -> 4
# few -> 4
# figure -> 4
# telling -> 4
# meet -> 4
# sometimes -> 4
# wall -> 4
# bad -> 4
# mother -> 4
# listen -> 4
# body -> 4
# friends -> 4
# pacman -> 4
# asshole -> 4
# grunts -> 4
# porn -> 4
# ah -> 4
# store -> 4
# hole -> 4
# eyes -> 4
# foreign -> 4
# holy -> 3
# denver -> 3
# wish -> 3
# hope -> 3
# also -> 3
# excited -> 3
# buy -> 3
# hold -> 3
# haven -> 3
# done -> 3
# open -> 3
# lost -> 3
# loss -> 3
# seen -> 3
# public -> 3
# times -> 3
# message -> 3
# starbucks -> 3
# wanted -> 3
# honest -> 3
# eating -> 3
# pick -> 3
# anymore -> 3
# clear -> 3
# line -> 3
# dick -> 3
# ass -> 3
# front -> 3
# goddamn -> 3
# specific -> 3
# seat -> 3
# racial -> 3
# cracker -> 3
# fun -> 3
# hand -> 3
# jobs -> 3
# beautiful -> 3
# second -> 3
# killed -> 3
# sure -> 3
# whatever -> 3
# city -> 3
# laws -> 3
# crazy -> 3
# stories -> 3
# percent -> 3
# understand -> 3
# responsibility -> 3
# tried -> 3
# inside -> 3
# imitates -> 3
# door -> 3
# mom -> 3
# fine -> 3
# vietnam -> 3
# movies -> 3
# threw -> 3
# feeling -> 3
# jesus -> 3
# sense -> 3
# morning -> 3
# picture -> 3
# dead -> 3
# close -> 3
# heard -> 3
# met -> 3
# hands -> 3
# born -> 3
# cincinnati -> 3
# impression -> 2
# super -> 2
# horny -> 2
# freshman -> 2
# college -> 2
# jump -> 2
# dorm -> 2
# hello -> 2
# booze -> 2
# truth -> 2
# late -> 2
# buying -> 2
# list -> 2
# wearing -> 2
# looks -> 2
# sees -> 2
# booth -> 2
# girl -> 2
# women -> 2
# pig -> 2
# both -> 2
# especially -> 2
# denial -> 2
# dmv -> 2
# read -> 2
# pfft -> 2
# office -> 2
# prostate -> 2
# until -> 2
# tested -> 2
# physical -> 2
# flaws -> 2
# uk -> 2
# hard -> 2
# without -> 2
# happens -> 2
# nice -> 2
# wear -> 2
# orange -> 2
# bring -> 2
# tourette -> 2
# eye -> 2
# greatest -> 2
# class -> 2
# bitch -> 2
# happening -> 2
# easy -> 2
# babies -> 2
# baby -> 2
# sleep -> 2
# masturbating -> 2
# parent -> 2
# shoes -> 2
# night -> 2
# offense -> 1
# literally -> 1
# whenever -> 1
# philosophizing -> 1
# leaving -> 1
# indicators -> 1
# paying -> 1
# attention -> 1
# process -> 1
# things -> 1
# couch -> 1
# bananas -> 1
# hammers -> 1
# eagle -> 1
# amazon -> 1
# insane -> 1
# device -> 1
# watching -> 1
# tv -> 1
# endless -> 1
# advertise -> 1
# snoring -> 1
# sleeping -> 1
# hours -> 1
# turd -> 1
# mechanical -> 1
# arm -> 1
# wan -> 1
# decent -> 1
# amount -> 1
# fattest -> 1
# earth -> 1
# may -> 1
# brent -> 1
# crystals -> 1
# beat -> 1
# thinking -> 1
# platform -> 1
# inspired -> 1
# mirror -> 1
# cry -> 1
# send -> 1
# grand -> 1
# scale -> 1
# helping -> 1
# national -> 1
# training -> 1
# campaign -> 1
# trick -> 1
# ordering -> 1
# beverage -> 1
# lead -> 1
# greet -> 1
# welcome -> 1
# sausage -> 1
# respect -> 1
# shame -> 1
# west -> 1
# coast -> 1
# chain -> 1
# together -> 1
# simply -> 1
# shameful -> 1
# fries -> 1
# bet -> 1
# fat -> 1
# pile -> 1
# sting -> 1
# bag -> 1
# tray -> 1
# falls -> 1
# lap -> 1
# hot -> 1
# dog -> 1
# french -> 1
# lonely -> 1
# milkshake -> 1
# bummin -> 1
# workers -> 1
# making -> 1
# sad -> 1
# arguments -> 1
# against -> 1
# shouldn -> 1
# bags -> 1
# smart -> 1
# extra -> 1
# chromosome -> 1
# damn -> 1
# abuse -> 1
# expression -> 1
# lie -> 1
# remotely -> 1
# sexual -> 1
# balloons -> 1
# overtly -> 1
# gay -> 1
# each -> 1
# marching -> 1
# cruel -> 1
# perfectly -> 1
# acceptable -> 1
# midget -> 1
# zoo -> 1
# feed -> 1
# lions -> 1
# child -> 1
# under -> 1
# slurs -> 1
# rip -> 1
# mick -> 1
# kraut -> 1
# polack -> 1
# frog -> 1
# guinea -> 1
# wop -> 1
# cares -> 1
# italian -> 1
# historically -> 1
# disenfranchised -> 1
# slur -> 1
# itself -> 1
# truly -> 1
# latched -> 1
# onto -> 1
# hillbilly -> 1
# pass -> 1
# hysterically -> 1
# stabbed -> 1
# quality -> 1
# kinda -> 1
# marker -> 1
# kevin -> 1
# crying -> 1
# herself -> 1
# teaching -> 1
# trust -> 1
# course -> 1
# easier -> 1
# seriously -> 1
# abandon -> 1
# inherently -> 1
# harder -> 1
# beginning -> 1
# complain -> 1
# bawl -> 1
# strangle -> 1
# below -> 1
# cuter -> 1
# bunnies -> 1
# puppies -> 1
# combined -> 1
# throw -> 1
# exchange -> 1
# rate -> 1
# please -> 1
# collectively -> 1
# society -> 1
# pushing -> 1
# myth -> 1
# necessary -> 1
# fall -> 1
# miniature -> 1
# version -> 1
# mostly -> 1
# fresh -> 1
# kissing -> 1
# populating -> 1
# martin -> 1
# luther -> 1
# crab -> 1
# legs -> 1
# sale -> 1
# costco -> 1
# sunday -> 1
# y -> 1
# parenthood -> 1
# till -> 1
# noon -> 1
# sip -> 1
# live -> 1
# forward -> 1
# sex -> 1
# treat -> 1
# dogs -> 1
# taunt -> 1
# grab -> 1
# exciting -> 1
# portland -> 1
# oregon -> 1
# afterwards -> 1
# noticed -> 1
# nikes -> 1
# headquarters -> 1
# employee -> 1
# warehouse -> 1
# product -> 1
# imaginable -> 1
# rent -> 1
# empty -> 1
# system -> 1
# flagged -> 1
# excuse -> 1
# entertainer -> 1
# influence -> 1
# fucked -> 1
# entertainment -> 1
# answers -> 1
# calling -> 1
# regroup -> 1
# adidas -> 1
# survive -> 1
# purchases -> 1
# company -> 1
# told -> 1
# york -> 1
# executive -> 1
# cell -> 1
# fingertips -> 1
# utilizing -> 1
# enough -> 1
# lexicon -> 1
# ultimate -> 1
# serious -> 1
# rappers -> 1
# videos -> 1
# president -> 1
# country -> 1
# appealing -> 1
# key -> 1
# secret -> 1
# physically -> 1
# horror -> 1
# shits -> 1
# closed -> 1
# often -> 1
# guessing -> 1
# twice -> 1
# cancun -> 1
# thai -> 1
# restaurant -> 1
# handle -> 1
# single -> 1
# makes -> 1
# contact -> 1
# pushes -> 1
# stares -> 1
# ugh -> 1
# nasty -> 1
# once -> 1
# cleaning -> 1

# %%
#print(stopwords.words('english'))
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Take all stop words out of the data
new_dict = {}

for key, value in sorted_dict.items():
    if key not in stop_words:
        new_dict[key] = value

# %%
new_dict
# Out:
# {'audience': 402,
#  'laughs': 380,
#  'like': 207,
#  'go': 107,
#  'goes': 89,
#  'know': 80,
#  'get': 46,
#  'people': 44,
#  'want': 40,
#  'fuck': 36,
#  'fuckin': 36,
#  'said': 36,
#  'right': 34,
#  'say': 34,
#  'see': 33,
#  'guy': 31,
#  'na': 30,
#  'shit': 29,
#  'think': 29,
#  'gon': 29,
#  'yeah': 28,
#  'would': 28,
#  'tell': 25,
#  'one': 25,
#  'got': 23,
#  'man': 21,
#  'time': 21,
#  'never': 20,
#  'clapping': 19,
#  'cheering': 18,
#  'dad': 18,
#  'oh': 17,
#  'look': 17,
#  'well': 16,
#  'years': 16,
#  'spanish': 16,
#  'ever': 15,
#  'give': 15,
#  'lot': 14,
#  'cause': 14,
#  'life': 13,
#  'let': 13,
#  'day': 13,
#  'white': 13,
#  'mean': 12,
#  'okay': 12,
#  'old': 12,
#  'first': 11,
#  'really': 11,
#  'something': 11,
#  'come': 11,
#  'going': 11,
#  'guys': 11,
#  'saying': 11,
#  'accent': 11,
#  'us': 10,
#  'ask': 10,
#  'back': 10,
#  'every': 10,
#  'park': 10,
#  'weed': 10,
#  'feel': 10,
#  'good': 9,
#  'laughing': 9,
#  'even': 9,
#  'hey': 9,
#  'take': 9,
#  'black': 9,
#  'thing': 9,
#  'speak': 9,
#  'thought': 8,
#  'leave': 8,
#  'sit': 8,
#  'saw': 8,
#  'bed': 8,
#  'little': 8,
#  'two': 8,
#  'weight': 8,
#  'mumbling': 8,
#  'best': 8,
#  'great': 8,
#  'happened': 8,
#  'watch': 8,
#  'mumbles': 8,
#  'went': 8,
#  'love': 8,
#  'kid': 8,
#  'stop': 8,
#  'way': 8,
#  'appreciate': 8,
#  'much': 7,
#  'home': 7,
#  'away': 7,
#  'talking': 7,
#  'try': 7,
#  'eat': 7,
#  'could': 7,
#  'next': 7,
#  'still': 7,
#  'walking': 7,
#  'last': 7,
#  'son': 7,
#  'show': 7,
#  'around': 7,
#  'lady': 7,
#  'woman': 7,
#  'funny': 7,
#  'vision': 7,
#  'walk': 6,
#  'place': 6,
#  'change': 6,
#  'means': 6,
#  'bah': 6,
#  'wait': 6,
#  'name': 6,
#  'better': 6,
#  'awesome': 6,
#  'many': 6,
#  'nobody': 6,
#  'house': 6,
#  'later': 6,
#  'ten': 6,
#  'honky': 6,
#  'hear': 6,
#  'god': 6,
#  'dude': 6,
#  'anybody': 6,
#  'face': 6,
#  'important': 6,
#  'asian': 6,
#  'new': 6,
#  'nike': 6,
#  'thank': 5,
#  'meaning': 5,
#  'always': 5,
#  'pretty': 5,
#  'anything': 5,
#  'comes': 5,
#  'sitting': 5,
#  'speaking': 5,
#  'person': 5,
#  'maybe': 5,
#  'probably': 5,
#  'food': 5,
#  'today': 5,
#  'car': 5,
#  'everybody': 5,
#  'remember': 5,
#  'used': 5,
#  'part': 5,
#  'word': 5,
#  'someone': 5,
#  'em': 5,
#  'call': 5,
#  'care': 5,
#  'believe': 5,
#  'fight': 5,
#  'shot': 5,
#  'another': 5,
#  'forget': 5,
#  'bought': 5,
#  'put': 5,
#  'trying': 5,
#  'trailer': 5,
#  'need': 5,
#  'kill': 5,
#  'year': 5,
#  'somebody': 5,
#  'story': 5,
#  'woodpecker': 5,
#  'make': 5,
#  'big': 5,
#  'shows': 5,
#  'moments': 5,
#  'building': 5,
#  'segura': 5,
#  'head': 5,
#  'football': 5,
#  'school': 5,
#  'sign': 5,
#  'looked': 5,
#  'motherfucker': 5,
#  'getting': 5,
#  'entire': 5,
#  'three': 5,
#  'finger': 5,
#  'british': 5,
#  'parts': 5,
#  'diaper': 5,
#  'whoa': 4,
#  'amazing': 4,
#  'whooping': 4,
#  'room': 4,
#  'number': 4,
#  'pull': 4,
#  'suck': 4,
#  'tired': 4,
#  'rest': 4,
#  'recently': 4,
#  'yes': 4,
#  'talk': 4,
#  'lose': 4,
#  'hit': 4,
#  'asked': 4,
#  'else': 4,
#  'question': 4,
#  'free': 4,
#  'situation': 4,
#  'friend': 4,
#  'ta': 4,
#  'might': 4,
#  'tom': 4,
#  'tomorrow': 4,
#  'called': 4,
#  'watched': 4,
#  'weird': 4,
#  'traumatized': 4,
#  'four': 4,
#  'kind': 4,
#  'marijuana': 4,
#  'walked': 4,
#  'cool': 4,
#  'figure': 4,
#  'telling': 4,
#  'meet': 4,
#  'sometimes': 4,
#  'wall': 4,
#  'bad': 4,
#  'mother': 4,
#  'listen': 4,
#  'body': 4,
#  'friends': 4,
#  'pacman': 4,
#  'asshole': 4,
#  'grunts': 4,
#  'porn': 4,
#  'ah': 4,
#  'store': 4,
#  'hole': 4,
#  'eyes': 4,
#  'foreign': 4,
#  'holy': 3,
#  'denver': 3,
#  'wish': 3,
#  'hope': 3,
#  'also': 3,
#  'excited': 3,
#  'buy': 3,
#  'hold': 3,
#  'done': 3,
#  'open': 3,
#  'lost': 3,
#  'loss': 3,
#  'seen': 3,
#  'public': 3,
#  'times': 3,
#  'message': 3,
#  'starbucks': 3,
#  'wanted': 3,
#  'honest': 3,
#  'eating': 3,
#  'pick': 3,
#  'anymore': 3,
#  'clear': 3,
#  'line': 3,
#  'dick': 3,
#  'ass': 3,
#  'front': 3,
#  'goddamn': 3,
#  'specific': 3,
#  'seat': 3,
#  'racial': 3,
#  'cracker': 3,
#  'fun': 3,
#  'hand': 3,
#  'jobs': 3,
#  'beautiful': 3,
#  'second': 3,
#  'killed': 3,
#  'sure': 3,
#  'whatever': 3,
#  'city': 3,
#  'laws': 3,
#  'crazy': 3,
#  'stories': 3,
#  'percent': 3,
#  'understand': 3,
#  'responsibility': 3,
#  'tried': 3,
#  'inside': 3,
#  'imitates': 3,
#  'door': 3,
#  'mom': 3,
#  'fine': 3,
#  'vietnam': 3,
#  'movies': 3,
#  'threw': 3,
#  'feeling': 3,
#  'jesus': 3,
#  'sense': 3,
#  'morning': 3,
#  'picture': 3,
#  'dead': 3,
#  'close': 3,
#  'heard': 3,
#  'met': 3,
#  'hands': 3,
#  'born': 3,
#  'cincinnati': 3,
#  'southern': 3,
#  'hotel': 3,
#  'japanese': 3,
#  'rude': 3,
#  'piss': 3,
#  'music': 3,
#  'point': 3,
#  'elevator': 3,
#  'power': 3,
#  'parking': 3,
#  'drive': 3,
#  'looking': 3,
#  'moment': 3,
#  'brake': 3,
#  'favorite': 3,
#  'game': 3,
#  'boy': 3,
#  'keep': 3,
#  'imagine': 3,
#  'allowed': 3,
#  'came': 3,
#  'giggles': 3,
#  'thanks': 3,
#  'behind': 3,
#  'stick': 3,
#  'men': 3,
#  'balls': 3,
#  'starts': 3,
#  'doctor': 3,
#  'bit': 3,
#  'laugh': 3,
#  'syndrome': 3,
#  'real': 3,
#  'chinese': 3,
#  'shirt': 3,
#  'cries': 3,
#  'cute': 3,
#  'selfless': 3,
#  'selfish': 3,
#  'shop': 3,
#  'insult': 3,
#  'personal': 2,
#  'wrap': 2,
#  'actually': 2,
#  'whistling': 2,
#  'luckily': 2,
#  'five': 2,
#  'homes': 2,
#  'order': 2,
#  'phone': 2,
#  'blows': 2,
#  'raspberry': 2,
#  'everyone': 2,
#  'indicator': 2,
#  'soon': 2,
#  'commercials': 2,
#  'beds': 2,
#  'air': 2,
#  'basically': 2,
#  'guess': 2,
#  'piece': 2,
#  'lay': 2,
#  'wake': 2,
#  'world': 2,
#  'pounds': 2,
#  'contest': 2,
#  'sucks': 2,
#  'messages': 2,
#  'coach': 2,
#  'absolutely': 2,
#  'hate': 2,
#  'ready': 2,
#  'true': 2,
#  'started': 2,
#  'burger': 2,
#  'experience': 2,
#  'fast': 2,
#  'living': 2,
#  'jerk': 2,
#  'retarded': 2,
#  'upset': 2,
#  'support': 2,
#  'describe': 2,
#  'idea': 2,
#  'water': 2,
#  'standing': 2,
#  'became': 2,
#  'offensive': 2,
#  'exactly': 2,
#  'group': 2,
#  'reason': 2,
#  'racist': 2,
#  'act': 2,
#  'run': 2,
#  'news': 2,
#  'find': 2,
#  'pay': 2,
#  'terrible': 2,
#  'fights': 2,
#  'across': 2,
#  'calls': 2,
#  'lived': 2,
#  'bushes': 2,
#  'instinctively': 2,
#  'took': 2,
#  'loyalty': 2,
#  'fantastic': 2,
#  'nation': 2,
#  'week': 2,
#  'highlights': 2,
#  'sell': 2,
#  'cars': 2,
#  'kick': 2,
#  'play': 2,
#  'explosion': 2,
#  'shoot': 2,
#  'parents': 2,
#  'stranger': 2,
#  'father': 2,
#  'work': 2,
#  'killing': 2,
#  'christmas': 2,
#  'brought': 2,
#  'ones': 2,
#  'found': 2,
#  'picked': 2,
#  'paid': 2,
#  'woke': 2,
#  'saturday': 2,
#  'asleep': 2,
#  'ear': 2,
#  'girlfriend': 2,
#  'family': 2,
#  'drop': 2,
#  'made': 2,
#  'loved': 2,
#  'long': 2,
#  'hi': 2,
#  'louisiana': 2,
#  'bunch': 2,
#  'realized': 2,
#  'whole': 2,
#  'inbreds': 2,
#  'hotels': 2,
#  'gruff': 2,
#  'voice': 2,
#  'sounds': 2,
#  'feels': 2,
#  'perfect': 2,
#  'english': 2,
#  'different': 2,
#  'either': 2,
#  'coming': 2,
#  'mouth': 2,
#  'supposed': 2,
#  'high': 2,
#  'singer': 2,
#  'sing': 2,
#  'songs': 2,
#  'left': 2,
#  'nut': 2,
#  'grunting': 2,
#  'sorry': 2,
#  'felt': 2,
#  'outside': 2,
#  'taste': 2,
#  'lives': 2,
#  'king': 2,
#  'blinker': 2,
#  'timing': 2,
#  'autograph': 2,
#  'thankfully': 2,
#  'buddies': 2,
#  'tough': 2,
#  'decides': 2,
#  'tunnel': 2,
#  'wondering': 2,
#  'grown': 2,
#  'biggest': 2,
#  'pac': 2,
#  'loves': 2,
#  'sent': 2,
#  'hell': 2,
#  'impression': 2,
#  'super': 2,
#  'horny': 2,
#  'freshman': 2,
#  'college': 2,
#  'jump': 2,
#  'dorm': 2,
#  'hello': 2,
#  'booze': 2,
#  'truth': 2,
#  'late': 2,
#  'buying': 2,
#  'list': 2,
#  'wearing': 2,
#  'looks': 2,
#  'sees': 2,
#  'booth': 2,
#  'girl': 2,
#  'women': 2,
#  'pig': 2,
#  'especially': 2,
#  'denial': 2,
#  'dmv': 2,
#  'read': 2,
#  'pfft': 2,
#  'office': 2,
#  'prostate': 2,
#  'tested': 2,
#  'physical': 2,
#  'flaws': 2,
#  'uk': 2,
#  'hard': 2,
#  'without': 2,
#  'happens': 2,
#  'nice': 2,
#  'wear': 2,
#  'orange': 2,
#  'bring': 2,
#  'tourette': 2,
#  'eye': 2,
#  'greatest': 2,
#  'class': 2,
#  'bitch': 2,
#  'happening': 2,
#  'easy': 2,
#  'babies': 2,
#  'baby': 2,
#  'sleep': 2,
#  'masturbating': 2,
#  'parent': 2,
#  'shoes': 2,
#  'night': 2,
#  'offense': 1,
#  'literally': 1,
#  'whenever': 1,
#  'philosophizing': 1,
#  'leaving': 1,
#  'indicators': 1,
#  'paying': 1,
#  'attention': 1,
#  'process': 1,
#  'things': 1,
#  'couch': 1,
#  'bananas': 1,
#  'hammers': 1,
#  'eagle': 1,
#  'amazon': 1,
#  'insane': 1,
#  'device': 1,
#  'watching': 1,
#  'tv': 1,
#  'endless': 1,
#  'advertise': 1,
#  'snoring': 1,
#  'sleeping': 1,
#  'hours': 1,
#  'turd': 1,
#  'mechanical': 1,
#  'arm': 1,
#  'wan': 1,
#  'decent': 1,
#  'amount': 1,
#  'fattest': 1,
#  'earth': 1,
#  'may': 1,
#  'brent': 1,
#  'crystals': 1,
#  'beat': 1,
#  'thinking': 1,
#  'platform': 1,
#  'inspired': 1,
#  'mirror': 1,
#  'cry': 1,
#  'send': 1,
#  'grand': 1,
#  'scale': 1,
#  'helping': 1,
#  'national': 1,
#  'training': 1,
#  'campaign': 1,
#  'trick': 1,
#  'ordering': 1,
#  'beverage': 1,
#  'lead': 1,
#  'greet': 1,
#  'welcome': 1,
#  'sausage': 1,
#  'respect': 1,
#  'shame': 1,
#  'west': 1,
#  'coast': 1,
#  'chain': 1,
#  'together': 1,
#  'simply': 1,
#  'shameful': 1,
#  'fries': 1,
#  'bet': 1,
#  'fat': 1,
#  'pile': 1,
#  'sting': 1,
#  'bag': 1,
#  'tray': 1,
#  'falls': 1,
#  'lap': 1,
#  'hot': 1,
#  'dog': 1,
#  'french': 1,
#  'lonely': 1,
#  'milkshake': 1,
#  'bummin': 1,
#  'workers': 1,
#  'making': 1,
#  'sad': 1,
#  'arguments': 1,
#  'bags': 1,
#  'smart': 1,
#  'extra': 1,
#  'chromosome': 1,
#  'damn': 1,
#  'abuse': 1,
#  'expression': 1,
#  'lie': 1,
#  'remotely': 1,
#  'sexual': 1,
#  'balloons': 1,
#  'overtly': 1,
#  'gay': 1,
#  'marching': 1,
#  'cruel': 1,
#  'perfectly': 1,
#  'acceptable': 1,
#  'midget': 1,
#  'zoo': 1,
#  'feed': 1,
#  'lions': 1,
#  'child': 1,
#  'slurs': 1,
#  'rip': 1,
#  'mick': 1,
#  'kraut': 1,
#  'polack': 1,
#  'frog': 1,
#  'guinea': 1,
#  'wop': 1,
#  'cares': 1,
#  'italian': 1,
#  'historically': 1,
#  'disenfranchised': 1,
#  'slur': 1,
#  'truly': 1,
#  'latched': 1,
#  'onto': 1,
#  'hillbilly': 1,
#  'pass': 1,
#  'hysterically': 1,
#  'stabbed': 1,
#  'quality': 1,
#  'kinda': 1,
#  'kiss': 1,
#  'philadelphia': 1,
#  'middle': 1,
#  'philly': 1,
#  'yells': 1,
#  'popped': 1,
#  'bush': 1,
#  'movie': 1,
#  'honey': 1,
#  'badger': 1,
#  'sprinted': 1,
#  'tackled': 1,
#  'realize': 1,
#  'turned': 1,
#  'record': 1,
#  'obvious': 1,
#  'torches': 1,
#  'jealous': 1,
#  'races': 1,
#  'asians': 1,
#  'dangerous': 1,
#  'involve': 1,
#  'account': 1,
#  'race': 1,
#  'core': 1,
#  'help': 1,
#  'murdered': 1,
#  'pictures': 1,
#  'beaten': 1,
#  'upload': 1,
#  'deadhonky': 1,
#  'republic': 1,
#  'already': 1,
#  'taken': 1,
#  'granted': 1,
#  'lax': 1,
#  'struggle': 1,
#  'acknowledge': 1,
#  'upbringing': 1,
#  'gave': 1,
#  'tape': 1,
#  'forehead': 1,
#  'gives': 1,
#  'horrific': 1,
#  'imprisoned': 1,
#  'absurdity': 1,
#  'illegal': 1,
#  'generation': 1,
#  'zero': 1,
#  'chance': 1,
#  'pigeons': 1,
#  'deliver': 1,
#  'age': 1,
#  'almost': 1,
#  'fire': 1,
#  'daddy': 1,
#  'chill': 1,
#  'round': 1,
#  'trips': 1,
#  'moving': 1,
#  'twenty': 1,
#  'dollars': 1,
#  'worth': 1,
#  'major': 1,
#  'solo': 1,
#  'terrifying': 1,
#  'housing': 1,
#  'exists': 1,
#  'sack': 1,
#  'sole': 1,
#  'stay': 1,
#  'shotgun': 1,
#  'blast': 1,
#  'paralysis': 1,
#  'pow': 1,
#  'stopped': 1,
#  'description': 1,
#  'agree': 1,
#  'terms': 1,
#  'height': 1,
#  'agrees': 1,
#  'vet': 1,
#  'war': 1,
#  'lieutenant': 1,
#  'charge': 1,
#  'grenades': 1,
#  'pieces': 1,
#  'talked': 1,
#  'stood': 1,
#  'sister': 1,
#  'smoke': 1,
#  'genuinely': 1,
#  'curious': 1,
#  'party': 1,
#  'pulled': 1,
#  'cigarette': 1,
#  'nerd': 1,
#  'viet': 1,
#  'cong': 1,
#  'marines': 1,
#  'throat': 1,
#  'ground': 1,
#  'bro': 1,
#  'woodpeckers': 1,
#  'damage': 1,
#  'patch': 1,
#  'month': 1,
#  'returned': 1,
#  'teenage': 1,
#  'whispering': 1,
#  'potent': 1,
#  'breath': 1,
#  'whispers': 1,
#  'rifle': 1,
#  'landed': 1,
#  'bigger': 1,
#  'red': 1,
#  'feathers': 1,
#  'distinct': 1,
#  'features': 1,
#  'blown': 1,
#  'bagged': 1,
#  'lunch': 1,
#  'mention': 1,
#  'ran': 1,
#  'wildlife': 1,
#  'conservation': 1,
#  'center': 1,
#  'forks': 1,
#  'endangered': 1,
#  'murmurs': 1,
#  'knowing': 1,
#  'enemy': 1,
#  'birds': 1,
#  'extinct': 1,
#  'obviously': 1,
#  'tour': 1,
#  'roll': 1,
#  'dice': 1,
#  'meeting': 1,
#  'lunatics': 1,
#  'shaking': 1,
#  'originally': 1,
#  'moved': 1,
#  'decipher': 1,
#  'lafayette': 1,
#  'miles': 1,
#  'south': 1,
#  'seguras': 1,
#  'population': 1,
#  'cajun': 1,
#  'amongst': 1,
#  'rights': 1,
#  'audacity': 1,
#  'redbox': 1,
#  'declare': 1,
#  'cartoon': 1,
#  'character': 1,
#  'state': 1,
#  'minds': 1,
#  'swamp': 1,
#  'miss': 1,
#  'shrimp': 1,
#  'contribution': 1,
#  'gator': 1,
#  'checked': 1,
#  'half': 1,
#  'dozen': 1,
#  'exaggerating': 1,
#  'begins': 1,
#  'usually': 1,
#  'standard': 1,
#  'desk': 1,
#  'hundred': 1,
#  'smith': 1,
#  'sushi': 1,
#  'chef': 1,
#  'accountant': 1,
#  'dash': 1,
#  'matters': 1,
#  'failed': 1,
#  'social': 1,
#  'studies': 1,
#  'geography': 1,
#  'mexico': 1,
#  'pants': 1,
#  'expect': 1,
#  'dim': 1,
#  'credit': 1,
#  'peruvian': 1,
#  'spoke': 1,
#  'reactions': 1,
#  'completely': 1,
#  'incredulous': 1,
#  'aramaic': 1,
#  'outta': 1,
#  'reaction': 1,
#  'played': 1,
#  'broncos': 1,
#  'giving': 1,
#  'capital': 1,
#  'mierda': 1,
#  'grew': 1,
#  'household': 1,
#  'listened': 1,
#  'influences': 1,
#  'become': 1,
#  'named': 1,
#  'juan': 1,
#  'luis': 1,
#  'guerra': 1,
#  'dominican': 1,
#  'titles': 1,
#  'si': 1,
#  'tu': 1,
#  'te': 1,
#  'lyrics': 1,
#  'heart': 1,
#  'balance': 1,
#  'todd': 1,
#  'shaw': 1,
#  'stage': 1,
#  'short': 1,
#  'blow': 1,
#  'job': 1,
#  'forth': 1,
#  'songwriters': 1,
#  'singing': 1,
#  'bust': 1,
#  'jaw': 1,
#  'sperm': 1,
#  'cheeks': 1,
#  'ya': 1,
#  'satisfying': 1,
#  'letting': 1,
#  'earlier': 1,
#  'warm': 1,
#  'rush': 1,
#  'hugged': 1,
#  'everyday': 1,
#  'alone': 1,
#  'lord': 1,
#  'shaft': 1,
#  'decide': 1,
#  'drawbridge': 1,
#  'opens': 1,
#  'nervous': 1,
#  'energy': 1,
#  'works': 1,
#  'buttons': 1,
#  'equal': 1,
#  'matter': 1,
#  'space': 1,
#  'mall': 1,
#  'shopping': 1,
#  'false': 1,
#  'waiting': 1,
#  'light': 1,
#  'marshals': 1,
#  'lights': 1,
#  'appear': 1,
#  'starting': 1,
#  'release': 1,
#  'tension': 1,
#  'rising': 1,
#  'snap': 1,
#  'hour': 1,
#  'philosophical': 1,
#  'wiping': 1,
#  'professional': 1,
#  'athlete': 1,
#  'answer': 1,
#  'adult': 1,
#  'bengals': 1,
#  'fan': 1,
#  'players': 1,
#  'autographs': 1,
#  'stadium': 1,
#  'heroes': 1,
#  'adam': 1,
#  'jones': 1,
#  'locker': 1,
#  'follow': 1,
#  'strip': 1,
#  'club': 1,
#  'vibe': 1,
#  'approachable': 1,
#  'whoo': 1,
#  'shitting': 1,
#  'knows': 1,
#  'walks': 1,
#  'end': 1,
#  'juxtaposition': 1,
#  'angrily': 1,
#  'incorporate': 1,
#  'airport': 1,
#  'bar': 1,
#  'flight': 1,
#  'bartender': 1,
#  'recognized': 1,
#  'working': 1,
#  'spot': 1,
#  'alarming': 1,
#  'students': 1,
#  'administrator': 1,
#  'narc': 1,
#  'birth': 1,
#  'street': 1,
#  'alcohol': 1,
#  'challenge': 1,
#  'liquor': 1,
#  'stores': 1,
#  'sir': 1,
#  'stock': 1,
#  'market': 1,
#  'pornography': 1,
#  'takes': 1,
#  'buffering': 1,
#  'kidding': 1,
#  'use': 1,
#  'mind': 1,
#  'couple': 1,
#  'freshmen': 1,
#  'dudes': 1,
#  'massive': 1,
#  'orders': 1,
#  'cash': 1,
#  'cocks': 1,
#  'asses': 1,
#  'feet': 1,
#  ...}

# %%
for key, value in new_dict.items():
    print(key, '->', value)
# Out:
# audience -> 402
# laughs -> 380
# like -> 207
# go -> 107
# goes -> 89
# know -> 80
# get -> 46
# people -> 44
# want -> 40
# fuck -> 36
# fuckin -> 36
# said -> 36
# right -> 34
# say -> 34
# see -> 33
# guy -> 31
# na -> 30
# shit -> 29
# think -> 29
# gon -> 29
# yeah -> 28
# would -> 28
# tell -> 25
# one -> 25
# got -> 23
# man -> 21
# time -> 21
# never -> 20
# clapping -> 19
# cheering -> 18
# dad -> 18
# oh -> 17
# look -> 17
# well -> 16
# years -> 16
# spanish -> 16
# ever -> 15
# give -> 15
# lot -> 14
# cause -> 14
# life -> 13
# let -> 13
# day -> 13
# white -> 13
# mean -> 12
# okay -> 12
# old -> 12
# first -> 11
# really -> 11
# something -> 11
# come -> 11
# going -> 11
# guys -> 11
# saying -> 11
# accent -> 11
# us -> 10
# ask -> 10
# back -> 10
# every -> 10
# park -> 10
# weed -> 10
# feel -> 10
# good -> 9
# laughing -> 9
# even -> 9
# hey -> 9
# take -> 9
# black -> 9
# thing -> 9
# speak -> 9
# thought -> 8
# leave -> 8
# sit -> 8
# saw -> 8
# bed -> 8
# little -> 8
# two -> 8
# weight -> 8
# mumbling -> 8
# best -> 8
# great -> 8
# happened -> 8
# watch -> 8
# mumbles -> 8
# went -> 8
# love -> 8
# kid -> 8
# stop -> 8
# way -> 8
# appreciate -> 8
# much -> 7
# home -> 7
# away -> 7
# talking -> 7
# try -> 7
# eat -> 7
# could -> 7
# next -> 7
# still -> 7
# walking -> 7
# last -> 7
# son -> 7
# show -> 7
# around -> 7
# lady -> 7
# woman -> 7
# funny -> 7
# vision -> 7
# walk -> 6
# place -> 6
# change -> 6
# means -> 6
# bah -> 6
# wait -> 6
# name -> 6
# better -> 6
# awesome -> 6
# many -> 6
# nobody -> 6
# house -> 6
# later -> 6
# ten -> 6
# honky -> 6
# hear -> 6
# god -> 6
# dude -> 6
# anybody -> 6
# face -> 6
# important -> 6
# asian -> 6
# new -> 6
# nike -> 6
# thank -> 5
# meaning -> 5
# always -> 5
# pretty -> 5
# anything -> 5
# comes -> 5
# sitting -> 5
# speaking -> 5
# person -> 5
# maybe -> 5
# probably -> 5
# food -> 5
# today -> 5
# car -> 5
# everybody -> 5
# remember -> 5
# used -> 5
# part -> 5
# word -> 5
# someone -> 5
# em -> 5
# call -> 5
# care -> 5
# believe -> 5
# fight -> 5
# shot -> 5
# another -> 5
# forget -> 5
# bought -> 5
# put -> 5
# trying -> 5
# trailer -> 5
# need -> 5
# kill -> 5
# year -> 5
# somebody -> 5
# story -> 5
# woodpecker -> 5
# make -> 5
# big -> 5
# shows -> 5
# moments -> 5
# building -> 5
# segura -> 5
# head -> 5
# football -> 5
# school -> 5
# sign -> 5
# looked -> 5
# motherfucker -> 5
# getting -> 5
# entire -> 5
# three -> 5
# finger -> 5
# british -> 5
# parts -> 5
# diaper -> 5
# whoa -> 4
# amazing -> 4
# whooping -> 4
# room -> 4
# number -> 4
# pull -> 4
# suck -> 4
# tired -> 4
# rest -> 4
# recently -> 4
# yes -> 4
# talk -> 4
# lose -> 4
# hit -> 4
# asked -> 4
# else -> 4
# question -> 4
# free -> 4
# situation -> 4
# friend -> 4
# ta -> 4
# might -> 4
# tom -> 4
# tomorrow -> 4
# called -> 4
# watched -> 4
# weird -> 4
# traumatized -> 4
# four -> 4
# kind -> 4
# marijuana -> 4
# walked -> 4
# cool -> 4
# figure -> 4
# telling -> 4
# meet -> 4
# sometimes -> 4
# wall -> 4
# bad -> 4
# mother -> 4
# listen -> 4
# body -> 4
# friends -> 4
# pacman -> 4
# asshole -> 4
# grunts -> 4
# porn -> 4
# ah -> 4
# store -> 4
# hole -> 4
# eyes -> 4
# foreign -> 4
# holy -> 3
# denver -> 3
# wish -> 3
# hope -> 3
# also -> 3
# excited -> 3
# buy -> 3
# hold -> 3
# done -> 3
# open -> 3
# lost -> 3
# loss -> 3
# seen -> 3
# public -> 3
# times -> 3
# message -> 3
# starbucks -> 3
# wanted -> 3
# honest -> 3
# eating -> 3
# pick -> 3
# anymore -> 3
# clear -> 3
# line -> 3
# dick -> 3
# ass -> 3
# front -> 3
# goddamn -> 3
# specific -> 3
# seat -> 3
# racial -> 3
# cracker -> 3
# fun -> 3
# hand -> 3
# jobs -> 3
# beautiful -> 3
# second -> 3
# killed -> 3
# sure -> 3
# whatever -> 3
# city -> 3
# laws -> 3
# crazy -> 3
# stories -> 3
# percent -> 3
# understand -> 3
# responsibility -> 3
# tried -> 3
# inside -> 3
# imitates -> 3
# door -> 3
# mom -> 3
# fine -> 3
# vietnam -> 3
# movies -> 3
# threw -> 3
# feeling -> 3
# jesus -> 3
# sense -> 3
# morning -> 3
# picture -> 3
# dead -> 3
# close -> 3
# heard -> 3
# met -> 3
# hands -> 3
# born -> 3
# cincinnati -> 3
# southern -> 3
# hotel -> 3
# dorm -> 2
# hello -> 2
# booze -> 2
# truth -> 2
# late -> 2
# buying -> 2
# list -> 2
# wearing -> 2
# looks -> 2
# sees -> 2
# booth -> 2
# girl -> 2
# women -> 2
# pig -> 2
# especially -> 2
# denial -> 2
# dmv -> 2
# read -> 2
# pfft -> 2
# office -> 2
# prostate -> 2
# tested -> 2
# physical -> 2
# flaws -> 2
# uk -> 2
# hard -> 2
# without -> 2
# happens -> 2
# nice -> 2
# wear -> 2
# orange -> 2
# bring -> 2
# tourette -> 2
# eye -> 2
# greatest -> 2
# class -> 2
# bitch -> 2
# happening -> 2
# easy -> 2
# babies -> 2
# baby -> 2
# sleep -> 2
# masturbating -> 2
# parent -> 2
# shoes -> 2
# night -> 2
# offense -> 1
# literally -> 1
# whenever -> 1
# philosophizing -> 1
# leaving -> 1
# indicators -> 1
# paying -> 1
# attention -> 1
# process -> 1
# things -> 1
# couch -> 1
# bananas -> 1
# hammers -> 1
# eagle -> 1
# amazon -> 1
# insane -> 1
# device -> 1
# watching -> 1
# tv -> 1
# endless -> 1
# advertise -> 1
# snoring -> 1
# sleeping -> 1
# hours -> 1
# turd -> 1
# mechanical -> 1
# arm -> 1
# wan -> 1
# decent -> 1
# amount -> 1
# fattest -> 1
# earth -> 1
# may -> 1
# brent -> 1
# crystals -> 1
# beat -> 1
# thinking -> 1
# platform -> 1
# inspired -> 1
# mirror -> 1
# cry -> 1
# send -> 1
# grand -> 1
# scale -> 1
# helping -> 1
# national -> 1
# training -> 1
# campaign -> 1
# trick -> 1
# ordering -> 1
# beverage -> 1
# lead -> 1
# greet -> 1
# welcome -> 1
# sausage -> 1
# respect -> 1
# shame -> 1
# west -> 1
# coast -> 1
# chain -> 1
# together -> 1
# simply -> 1
# shameful -> 1
# fries -> 1
# bet -> 1
# fat -> 1
# pile -> 1
# sting -> 1
# bag -> 1
# tray -> 1
# falls -> 1
# lap -> 1
# hot -> 1
# dog -> 1
# french -> 1
# lonely -> 1
# milkshake -> 1
# bummin -> 1
# workers -> 1
# making -> 1
# sad -> 1
# arguments -> 1
# bags -> 1
# smart -> 1
# extra -> 1
# chromosome -> 1
# damn -> 1
# abuse -> 1
# expression -> 1
# lie -> 1
# remotely -> 1
# sexual -> 1
# balloons -> 1
# overtly -> 1
# gay -> 1
# marching -> 1
# cruel -> 1
# perfectly -> 1
# acceptable -> 1
# midget -> 1
# zoo -> 1
# feed -> 1
# lions -> 1
# child -> 1
# slurs -> 1
# rip -> 1
# mick -> 1
# kraut -> 1
# polack -> 1
# frog -> 1
# guinea -> 1
# wop -> 1
# cares -> 1
# italian -> 1
# historically -> 1
# disenfranchised -> 1
# slur -> 1
# truly -> 1
# latched -> 1
# onto -> 1
# hillbilly -> 1
# pass -> 1
# hysterically -> 1
# stabbed -> 1
# quality -> 1
# kinda -> 1
# kiss -> 1
# philadelphia -> 1
# middle -> 1
# philly -> 1
# yells -> 1
# popped -> 1
# bush -> 1
# movie -> 1
# honey -> 1
# badger -> 1
# sprinted -> 1
# tackled -> 1
# cuter -> 1
# bunnies -> 1
# puppies -> 1
# combined -> 1
# throw -> 1
# exchange -> 1
# rate -> 1
# please -> 1
# collectively -> 1
# society -> 1
# pushing -> 1
# myth -> 1
# necessary -> 1
# fall -> 1
# miniature -> 1
# version -> 1
# mostly -> 1
# fresh -> 1
# kissing -> 1
# populating -> 1
# martin -> 1
# luther -> 1
# crab -> 1
# legs -> 1
# sale -> 1
# costco -> 1
# sunday -> 1
# parenthood -> 1
# till -> 1
# noon -> 1
# sip -> 1
# live -> 1
# forward -> 1
# sex -> 1
# treat -> 1
# dogs -> 1
# taunt -> 1
# grab -> 1
# exciting -> 1
# portland -> 1
# oregon -> 1
# afterwards -> 1
# noticed -> 1
# nikes -> 1
# headquarters -> 1
# employee -> 1
# warehouse -> 1
# product -> 1
# imaginable -> 1
# rent -> 1
# empty -> 1
# system -> 1
# flagged -> 1
# excuse -> 1
# entertainer -> 1
# influence -> 1
# fucked -> 1
# entertainment -> 1
# answers -> 1
# calling -> 1
# regroup -> 1
# adidas -> 1
# survive -> 1
# purchases -> 1
# company -> 1
# told -> 1
# york -> 1
# executive -> 1
# cell -> 1
# fingertips -> 1
# utilizing -> 1
# enough -> 1
# lexicon -> 1
# ultimate -> 1
# serious -> 1
# rappers -> 1
# videos -> 1
# president -> 1
# country -> 1
# appealing -> 1
# key -> 1
# secret -> 1
# physically -> 1
# horror -> 1
# shits -> 1
# closed -> 1
# often -> 1
# guessing -> 1
# twice -> 1
# cancun -> 1
# thai -> 1
# restaurant -> 1
# handle -> 1
# single -> 1
# makes -> 1
# contact -> 1
# pushes -> 1
# stares -> 1
# ugh -> 1
# nasty -> 1
# cleaning -> 1

# %%
useless_words = ['gon', 'go', 'know', 'right', 'got', 'one', 'get', 'yeah', 'good', 'go', 'thank', 'say', 'come', 'oh', 'make', 'really', 'two', 'applause', 
                 'let', 'going', 'audience', 'made', 'way', 'us', 'see', 'great', 'want', 'lot', 'way', 'ta', 'take', 'cause', 'attell', 'something',
                 'em', 'real', 'better', 'wan', 'show', 'back', 'well', 'even', 'never', 'tell', 'keep', 'away', 'much', 'things', 'time', 'ever'
                'welcome', 'cause', 'please', 'okay', 'would', 'like', 'na', 'ever', 'laughs', 'goes', 'people', 'said', 'guy', 'claping', 'cheering', 'give'
                'day', 'clapping', 'clapping ', 'give', 'first', 'saying', 'ask', 'every', 'laughing']

# %%
new_dict_2 = {}

for key, value in new_dict.items():
    if key not in useless_words:
        new_dict_2[key] = value
for key, value in new_dict_2.items():
    print(key, '->', value)
# Out:
# fuck -> 36
# fuckin -> 36
# shit -> 29
# think -> 29
# man -> 21
# dad -> 18
# look -> 17
# years -> 16
# spanish -> 16
# life -> 13
# day -> 13
# white -> 13
# mean -> 12
# old -> 12
# guys -> 11
# accent -> 11
# park -> 10
# weed -> 10
# feel -> 10
# hey -> 9
# black -> 9
# thing -> 9
# speak -> 9
# thought -> 8
# leave -> 8
# sit -> 8
# saw -> 8
# bed -> 8
# little -> 8
# weight -> 8
# mumbling -> 8
# best -> 8
# happened -> 8
# watch -> 8
# mumbles -> 8
# went -> 8
# love -> 8
# kid -> 8
# stop -> 8
# appreciate -> 8
# home -> 7
# talking -> 7
# try -> 7
# eat -> 7
# could -> 7
# next -> 7
# still -> 7
# walking -> 7
# last -> 7
# son -> 7
# around -> 7
# lady -> 7
# woman -> 7
# funny -> 7
# vision -> 7
# walk -> 6
# place -> 6
# change -> 6
# means -> 6
# bah -> 6
# wait -> 6
# name -> 6
# awesome -> 6
# many -> 6
# nobody -> 6
# house -> 6
# later -> 6
# ten -> 6
# honky -> 6
# hear -> 6
# god -> 6
# dude -> 6
# anybody -> 6
# face -> 6
# important -> 6
# asian -> 6
# new -> 6
# nike -> 6
# meaning -> 5
# always -> 5
# pretty -> 5
# anything -> 5
# comes -> 5
# sitting -> 5
# speaking -> 5
# person -> 5
# maybe -> 5
# probably -> 5
# food -> 5
# today -> 5
# car -> 5
# everybody -> 5
# remember -> 5
# used -> 5
# part -> 5
# word -> 5
# someone -> 5
# call -> 5
# care -> 5
# believe -> 5
# fight -> 5
# shot -> 5
# another -> 5
# forget -> 5
# bought -> 5
# put -> 5
# trying -> 5
# trailer -> 5
# need -> 5
# kill -> 5
# year -> 5
# somebody -> 5
# story -> 5
# woodpecker -> 5
# big -> 5
# shows -> 5
# moments -> 5
# building -> 5
# segura -> 5
# head -> 5
# football -> 5
# school -> 5
# sign -> 5
# looked -> 5
# motherfucker -> 5
# getting -> 5
# entire -> 5
# three -> 5
# finger -> 5
# british -> 5
# parts -> 5
# diaper -> 5
# whoa -> 4
# amazing -> 4
# whooping -> 4
# room -> 4
# number -> 4
# pull -> 4
# suck -> 4
# tired -> 4
# rest -> 4
# recently -> 4
# yes -> 4
# talk -> 4
# lose -> 4
# hit -> 4
# asked -> 4
# else -> 4
# question -> 4
# free -> 4
# situation -> 4
# friend -> 4
# might -> 4
# tom -> 4
# tomorrow -> 4
# called -> 4
# watched -> 4
# weird -> 4
# traumatized -> 4
# four -> 4
# kind -> 4
# marijuana -> 4
# walked -> 4
# cool -> 4
# figure -> 4
# telling -> 4
# meet -> 4
# sometimes -> 4
# wall -> 4
# bad -> 4
# mother -> 4
# listen -> 4
# body -> 4
# friends -> 4
# pacman -> 4
# asshole -> 4
# grunts -> 4
# porn -> 4
# ah -> 4
# store -> 4
# hole -> 4
# eyes -> 4
# foreign -> 4
# holy -> 3
# denver -> 3
# wish -> 3
# hope -> 3
# also -> 3
# excited -> 3
# buy -> 3
# hold -> 3
# done -> 3
# open -> 3
# lost -> 3
# loss -> 3
# seen -> 3
# public -> 3
# times -> 3
# message -> 3
# starbucks -> 3
# wanted -> 3
# honest -> 3
# eating -> 3
# pick -> 3
# anymore -> 3
# clear -> 3
# line -> 3
# dick -> 3
# ass -> 3
# front -> 3
# goddamn -> 3
# specific -> 3
# seat -> 3
# racial -> 3
# cracker -> 3
# fun -> 3
# hand -> 3
# jobs -> 3
# beautiful -> 3
# second -> 3
# killed -> 3
# sure -> 3
# whatever -> 3
# exaggerating -> 1
# begins -> 1
# usually -> 1
# standard -> 1
# desk -> 1
# hundred -> 1
# smith -> 1
# sushi -> 1
# chef -> 1
# accountant -> 1
# dash -> 1
# matters -> 1
# failed -> 1
# social -> 1
# studies -> 1
# geography -> 1
# mexico -> 1
# pants -> 1
# expect -> 1
# dim -> 1
# credit -> 1
# peruvian -> 1
# spoke -> 1
# reactions -> 1
# completely -> 1
# incredulous -> 1
# aramaic -> 1
# outta -> 1
# reaction -> 1
# played -> 1
# broncos -> 1
# giving -> 1
# capital -> 1
# mierda -> 1
# grew -> 1
# household -> 1
# listened -> 1
# influences -> 1
# become -> 1
# named -> 1
# juan -> 1
# luis -> 1
# guerra -> 1
# dominican -> 1
# titles -> 1
# si -> 1
# tu -> 1
# te -> 1
# lyrics -> 1
# heart -> 1
# balance -> 1
# todd -> 1
# shaw -> 1
# stage -> 1
# short -> 1
# blow -> 1
# job -> 1
# forth -> 1
# songwriters -> 1
# singing -> 1
# bust -> 1
# jaw -> 1
# sperm -> 1
# cheeks -> 1
# ya -> 1
# satisfying -> 1
# letting -> 1
# earlier -> 1
# warm -> 1
# rush -> 1
# hugged -> 1
# everyday -> 1
# alone -> 1
# lord -> 1
# shaft -> 1
# decide -> 1
# drawbridge -> 1
# opens -> 1
# nervous -> 1
# energy -> 1
# works -> 1
# buttons -> 1
# equal -> 1
# matter -> 1
# space -> 1
# mall -> 1
# shopping -> 1
# false -> 1
# waiting -> 1
# light -> 1
# marshals -> 1
# lights -> 1
# appear -> 1
# starting -> 1
# release -> 1
# tension -> 1
# rising -> 1
# snap -> 1
# hour -> 1
# philosophical -> 1
# wiping -> 1
# professional -> 1
# athlete -> 1
# answer -> 1
# adult -> 1
# bengals -> 1
# fan -> 1
# players -> 1
# autographs -> 1
# stadium -> 1
# heroes -> 1
# adam -> 1
# jones -> 1
# locker -> 1
# follow -> 1
# strip -> 1
# club -> 1
# vibe -> 1
# approachable -> 1
# whoo -> 1
# shitting -> 1
# knows -> 1
# walks -> 1
# end -> 1
# juxtaposition -> 1
# angrily -> 1
# incorporate -> 1
# airport -> 1
# bar -> 1
# flight -> 1
# bartender -> 1
# recognized -> 1
# working -> 1
# spot -> 1
# alarming -> 1
# students -> 1
# administrator -> 1
# narc -> 1
# birth -> 1
# street -> 1
# alcohol -> 1
# challenge -> 1
# liquor -> 1
# stores -> 1
# sir -> 1
# stock -> 1
# market -> 1
# pornography -> 1
# takes -> 1
# buffering -> 1
# kidding -> 1
# use -> 1
# mind -> 1
# couple -> 1
# freshmen -> 1
# dudes -> 1
# massive -> 1
# orders -> 1
# cash -> 1
# cocks -> 1
# asses -> 1
# feet -> 1
# psychopath -> 1
# grocery -> 1
# fakes -> 1
# laughter -> 1
# outrageous -> 1
# amounts -> 1
# owner -> 1
# customer -> 1
# sends -> 1
# address -> 1
# overalls -> 1
# international -> 1
# uniform -> 1
# counter -> 1
# words -> 1
# fetish -> 1
# full -> 1
# bladder -> 1
# waste -> 1
# among -> 1
# toys -> 1
# somehow -> 1
# chapter -> 1
# ticks -> 1
# build -> 1
# start -> 1
# small -> 1
# gasps -> 1
# markers -> 1
# paint -> 1
# painting -> 1
# marker -> 1
# kevin -> 1
# crying -> 1
# teaching -> 1
# trust -> 1
# course -> 1
# easier -> 1
# seriously -> 1
# abandon -> 1
# inherently -> 1
# harder -> 1
# beginning -> 1
# complain -> 1
# bawl -> 1
# strangle -> 1
# cuter -> 1
# bunnies -> 1
# puppies -> 1
# combined -> 1
# throw -> 1
# exchange -> 1
# rate -> 1
# collectively -> 1
# society -> 1
# pushing -> 1
# myth -> 1
# necessary -> 1
# fall -> 1
# miniature -> 1
# version -> 1
# mostly -> 1
# fresh -> 1
# kissing -> 1
# populating -> 1
# martin -> 1
# luther -> 1
# crab -> 1
# legs -> 1
# sale -> 1
# costco -> 1
# sunday -> 1
# parenthood -> 1
# till -> 1
# noon -> 1
# sip -> 1
# live -> 1
# forward -> 1
# sex -> 1
# treat -> 1
# dogs -> 1
# taunt -> 1
# grab -> 1
# exciting -> 1
# portland -> 1
# oregon -> 1
# afterwards -> 1
# noticed -> 1
# nikes -> 1
# headquarters -> 1
# employee -> 1
# warehouse -> 1
# product -> 1
# imaginable -> 1
# rent -> 1
# empty -> 1
# system -> 1
# flagged -> 1
# excuse -> 1
# entertainer -> 1
# influence -> 1
# fucked -> 1
# entertainment -> 1
# answers -> 1
# calling -> 1
# regroup -> 1
# adidas -> 1
# survive -> 1
# purchases -> 1
# company -> 1
# told -> 1
# york -> 1
# executive -> 1
# cell -> 1
# fingertips -> 1
# utilizing -> 1
# enough -> 1
# lexicon -> 1
# ultimate -> 1
# serious -> 1
# rappers -> 1
# videos -> 1
# president -> 1
# country -> 1
# appealing -> 1
# key -> 1
# secret -> 1
# physically -> 1
# horror -> 1
# shits -> 1
# closed -> 1
# often -> 1
# guessing -> 1
# twice -> 1
# cancun -> 1
# thai -> 1
# restaurant -> 1
# handle -> 1
# single -> 1
# makes -> 1
# contact -> 1
# pushes -> 1
# stares -> 1
# ugh -> 1
# nasty -> 1
# cleaning -> 1

# %%
races = ['black', 'white', 'yellow', 'asian']
race_dict = {}
for key, value in new_dict.items():
    if key in races:
        race_dict[key] = value

race_dict
# Out:
# {'white': 13, 'black': 9, 'asian': 6}

# %%
words = []
values = []

for i in range(20):
    words.append(list(new_dict_2.keys())[i])
    values.append(list(new_dict_2.values())[i])

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('Solarize_Light2')

# %%
plt.style.use('fivethirtyeight')

# %%
plt.style.use('seaborn-pastel')

# %%
plt.style.use('seaborn-white')

# %%
plt.style.use('tableau-colorblind10')

# %%
fig = plt.figure(figsize = (15, 15))

plt.rc('ytick', labelsize=13)
plt.barh(words,values)

plt.gca().invert_yaxis()

plt.xlabel("# of Times Said", fontsize=15, fontweight='bold')
plt.ylabel("Words Used", fontsize=18, fontweight='bold')
plt.title("Most common words in 'Disgraceful' by Tom Segura", fontsize=15)

plt.savefig('Disgraceful - Tom Segura.jpg',bbox_inches='tight', dpi=150) #jpg?
plt.show()
